# %%
import pandas as pd
import numpy as np


file_path = "../Data/random_pc_r_5_da_2_bal/all_preds_gramneg_capsid.pkl"
df = pd.read_pickle(file_path)
display(df.head(10))
# Out:
#                 Vibrio_capsid  Pseudomonas_capsid  Salmonella_capsid  \
# proteinID
# AB002632_00003       0.892029            0.006306           0.009383
# AB002632_00005       0.884198            0.039370           0.016259
# AB002632_00006       0.960939            0.002251           0.005723
# AB002632_00007       0.887575            0.009491           0.011740
# AB008550_00005       0.003117            0.052489           0.009547
# AB012573_00004       0.930251            0.003667           0.018491
# AB012573_00005       0.911129            0.003276           0.005064
# AB012573_00006       0.930109            0.345965           0.014381
# AB012574_00004       0.930251            0.003667           0.018491
# AB012574_00005       0.911129            0.003276           0.005064
#
#                 Microcystis_capsid  Escherichia_capsid  Ralstonia_capsid  \
# proteinID
# AB002632_00003            0.081754            0.041862          0.003088
# ...

# %%
file_path = "../Data/random_pc_r_5_da_2_bal/all_preds_gramneg_adsorption-related.pkl"
df = pd.read_pickle(file_path)
# display(df.head(10))
display(df)
# Out:
#                 Vibrio_adsorption-related  Pseudomonas_adsorption-related  \
# proteinID
# AB002632_00006                   0.969125                        0.007314
# AB008550_00017                   0.000129                        0.948174
# AB008550_00021                   0.001836                        0.988712
# AB008550_00022                   0.000398                        0.131704
# AB012573_00005                   0.989906                        0.002179
# ...                                   ...                             ...
# X60322_00009                     0.022871                        0.021480
# X60323_00008                     0.008813                        0.006514
# Y13918_00017                     0.000129                        0.948174
# Y13918_00021                     0.001836                        0.988712
# Y13918_00022                     0.000398                        0.131704
#
# ...

# %%
import os

# Get the list of all files and directories
# Remove the leading slash
path = "../Data/random_pc_r_5_da_2_bal"
files = os.listdir(path)

for file in files:
    print(file)
# Out:
# all_preds_grampos_terminase.pkl
# all_preds_grampos_adsorption-related.pkl
# all_preds_gramneg_spanin.pkl
# all_preds_gramneg_val.pkl
# all_preds_gramneg_cell_wall_depolymerase.pkl
# all_preds_gramneg_transcriptional_activator.pkl
# all_preds_gramneg_endolysin.pkl
# all_preds_gramneg_super_infection.pkl
# all_preds_grampos_transcriptional_repressor.pkl
# all_preds_gramneg_transcriptional_repressor.pkl
# all_preds_grampos_DNA_polymerase.pkl
# all_preds_grampos_nuclease.pkl
# all_preds_gramneg_DNA-associated_1.pkl
# all_preds_grampos_sir2.pkl
# all_preds_grampos_tail.pkl
# all_preds_gramneg_tail_sheath.pkl
# all_preds_gramneg_nucleotide_metabolism.pkl
# all_preds_grampos_spanin.pkl
# all_preds_grampos_integration.pkl
# all_preds_grampos_transferase.pkl
# all_preds_gramneg_nuclease.pkl
# all_preds_gramneg_replication_initiation.pkl
# all_preds_gramneg_reductase.pkl
# all_preds_grampos_nucleotide_metabolism.pkl
# all_preds_grampos_transcriptional_regulator.pkl
# ...

# %%
file_path = "../Data/all_random_pc_splits.pkl"
df = pd.read_pickle(file_path)
# display(df.head(10))
display(df)
# Out:
#                 split_Campylobacter_lysin  split_Campylobacter_endolysin  \
# proteinID
# AB002632_00001                       <NA>                           <NA>
# AB002632_00002                       <NA>                           <NA>
# AB002632_00003                       <NA>                           <NA>
# AB002632_00004                       <NA>                           <NA>
# AB002632_00005                       <NA>                           <NA>
# ...                                   ...                            ...
# Z47794_00023                         <NA>                           <NA>
# Z47794_00024                         <NA>                           <NA>
# Z47794_00025                         <NA>                           <NA>
# Z47794_00026                         <NA>                           <NA>
# Z47794_00027                         <NA>                           <NA>
#
#                 split_Campylobacter_val  split_Caulobacter_lysin  \
# proteinID
# ...

# %%
file_path = "../Data/embeddings.pkl"
df = pd.read_pickle(file_path)
# display(df.head(10))
display(df)
# Out:
#                        0         1         2         3         4         5  \
# proteinID
# AB002632_00001  0.013371 -0.035044 -0.035994  0.057320  0.019145  0.011627
# AB002632_00002  0.022211 -0.091248  0.051000  0.059318 -0.033121  0.009205
# AB002632_00003  0.062245 -0.033898  0.070273 -0.030639  0.024119  0.014112
# AB002632_00004  0.018732  0.050848  0.009785  0.000267 -0.057730  0.011694
# AB002632_00005  0.027054 -0.093019  0.016626 -0.004320  0.064356  0.010339
# ...                  ...       ...       ...       ...       ...       ...
# Z47794_00023    0.022563  0.003806  0.028419 -0.096477 -0.009286 -0.009857
# Z47794_00024   -0.005002  0.022848  0.080614 -0.017445 -0.008448  0.016226
# Z47794_00025   -0.014739  0.036652  0.030701 -0.027894 -0.072174  0.049856
# Z47794_00026    0.035646  0.125420 -0.044289 -0.032611 -0.042168  0.014855
# Z47794_00027    0.045422 -0.006953 -0.006277  0.002371  0.003399 -0.022768
#
# ...

# %%
file_path = "../Data/functional_predictions.pkl"
df = pd.read_pickle(file_path)
# display(df.head(10))
display(df)
# Out:
#                    lysin  endolysin  val       pvp    capsid  major_capsid  \
# proteinID
# AB002632_00001  0.001376        NaN  NaN  0.046736       NaN           NaN
# AB002632_00002  0.000007        NaN  NaN  0.017311       NaN           NaN
# AB002632_00003  0.000215        NaN  NaN  0.582806  0.978879      0.008960
# AB002632_00004  0.000719        NaN  NaN  0.066260       NaN           NaN
# AB002632_00005  0.000038        NaN  NaN  0.995377  0.992280      0.999998
# ...                  ...        ...  ...       ...       ...           ...
# Z47794_00023    0.000323        NaN  NaN  0.080922       NaN           NaN
# Z47794_00024    0.000753        NaN  NaN  0.029592       NaN           NaN
# Z47794_00025    0.000090        NaN  NaN  0.044169       NaN           NaN
# Z47794_00026    0.000369        NaN  NaN  0.018680       NaN           NaN
# Z47794_00027    0.000233        NaN  NaN  0.010475       NaN           NaN
#
# ...
