# %%
import sys
import numpy
import pandas as pd
sys.modules['numpy._core'] = numpy.core

# %%
METADATA_PATH = "../Data/metadata.csv"
print("Loading metadata...")
meta_df = pd.read_csv(METADATA_PATH, index_col="proteinID")
print(f"  metadata shape : {meta_df.shape}")
print(meta_df.head(10))
# Out:
# Loading metadata...
#   metadata shape : (1853074, 8)
#                             pc accession      vc    host host_type  \
# proteinID
# AB002632_00001  KP972568_00002  AB002632  VC_0_0  Vibrio  gram-neg
# AB002632_00002  OP297622_00003  AB002632  VC_0_0  Vibrio  gram-neg
# AB002632_00003  KC357596_00003  AB002632  VC_0_0  Vibrio  gram-neg
# AB002632_00004  AB002632_00004  AB002632  VC_0_0  Vibrio  gram-neg
# AB002632_00005  AB002632_00005  AB002632  VC_0_0  Vibrio  gram-neg
# AB002632_00006  AB002632_00006  AB002632  VC_0_0  Vibrio  gram-neg
# AB002632_00007  AB002632_00007  AB002632  VC_0_0  Vibrio  gram-neg
# AB002632_00008    J02451_00006  AB002632  VC_0_0  Vibrio  gram-neg
# AB002632_00009  AB002632_00009  AB002632  VC_0_0  Vibrio  gram-neg
# AB002632_00010  AB002632_00010  AB002632  VC_0_0  Vibrio  gram-neg
#
#                                    phrogs_annotation  \
# proteinID
# AB002632_00001      nicking at origin of replication
# AB002632_00002     single strand DNA binding protein
# AB002632_00003                    minor coat protein
# AB002632_00004                    minor head protein
# AB002632_00005                    major coat protein
# AB002632_00006  minor head protein; receptor binding
# AB002632_00007                    minor head protein
# AB002632_00008      morphogenesis (protein I of M13)
# AB002632_00009          assembly (protein IV of M13)
# AB002632_00010                 tail assembly protein
#
#                                    phrogs_category  split
# proteinID
# AB002632_00001  DNA, RNA and nucleotide metabolism      0
# AB002632_00002  DNA, RNA and nucleotide metabolism      0
# AB002632_00003                  head and packaging      0
# AB002632_00004                  head and packaging      0
# AB002632_00005                  head and packaging      0
# AB002632_00006                  head and packaging      0
# AB002632_00007                  head and packaging      0
# AB002632_00008                  head and packaging      0
# AB002632_00009                  head and packaging      0
# AB002632_00010                                tail      0

# %%
SCORES_PATH = "../Data/host_type_all_preds.csv"

print("Loading scores...")
# scores_df = pd.read_csv(SCORES_PATH, index_col="proteinID")
scores_df = pd.read_csv(SCORES_PATH, index_col=0)
print(f"  scores shape : {scores_df.shape}  ")
print(scores_df.head(10))
# Out:
# Loading scores...
#   scores shape : (1853074, 40)
#                 host_type_lysin  host_type_endolysin  host_type_val  \
# proteinID
# AB002632_00001              NaN                  NaN            NaN
# AB002632_00002              NaN                  NaN            NaN
# AB002632_00003              NaN                  NaN            NaN
# AB002632_00004              NaN                  NaN            NaN
# AB002632_00005              NaN                  NaN            NaN
# AB002632_00006              NaN                  NaN            NaN
# AB002632_00007              NaN                  NaN            NaN
# AB002632_00008              NaN                  NaN            NaN
# AB002632_00009              NaN                  NaN            NaN
# AB002632_00010              NaN                  NaN            NaN
#
#                 host_type_capsid  host_type_baseplate  \
# proteinID
# AB002632_00001               NaN                  NaN
# AB002632_00002               NaN                  NaN
# AB002632_00003          0.029791                  NaN
# AB002632_00004               NaN                  NaN
# AB002632_00005          0.008570                  NaN
# AB002632_00006          0.011765                  NaN
# AB002632_00007          0.010422                  NaN
# AB002632_00008               NaN                  NaN
# AB002632_00009               NaN                  NaN
# AB002632_00010               NaN                  NaN
#
#                 host_type_tail_appendage  host_type_tail_sheath  \
# proteinID
# AB002632_00001                       NaN                    NaN
# AB002632_00002                       NaN                    NaN
# AB002632_00003                       NaN                    NaN
# AB002632_00004                       NaN                    NaN
# AB002632_00005                       NaN                    NaN
# AB002632_00006                       NaN                    NaN
# AB002632_00007                       NaN                    NaN
# AB002632_00008                       NaN                    NaN
# AB002632_00009                       NaN                    NaN
# AB002632_00010                       NaN                    NaN
#
#                 host_type_portal  host_type_head-tail_joining  \
# proteinID
# AB002632_00001               NaN                          NaN
# AB002632_00002               NaN                          NaN
# AB002632_00003               NaN                          NaN
# AB002632_00004               NaN                          NaN
# AB002632_00005               NaN                          NaN
# AB002632_00006               NaN                          NaN
# AB002632_00007               NaN                          NaN
# AB002632_00008               NaN                          NaN
# AB002632_00009               NaN                          NaN
# AB002632_00010               NaN                          NaN
#
#                 host_type_integration  ...  host_type_sir2  host_type_toxin  \
# proteinID                              ...
# AB002632_00001                    NaN  ...             NaN              NaN
# AB002632_00002                    NaN  ...             NaN              NaN
# AB002632_00003                    NaN  ...             NaN              NaN
# AB002632_00004                    NaN  ...             NaN              NaN
# AB002632_00005                    NaN  ...             NaN              NaN
# AB002632_00006                    NaN  ...             NaN              NaN
# AB002632_00007                    NaN  ...             NaN              NaN
# AB002632_00008                    NaN  ...             NaN         0.021113
# AB002632_00009                    NaN  ...             NaN              NaN
# AB002632_00010                    NaN  ...             NaN              NaN
#
#                 host_type_super_infection  host_type_lysis  \
# proteinID
# AB002632_00001                        NaN              NaN
# AB002632_00002                        NaN              NaN
# AB002632_00003                        NaN              NaN
# AB002632_00004                        NaN              NaN
# AB002632_00005                        NaN              NaN
# AB002632_00006                        NaN              NaN
# AB002632_00007                        NaN              NaN
# AB002632_00008                        NaN              NaN
# AB002632_00009                        NaN              NaN
# AB002632_00010                        NaN              NaN
#
#                 host_type_lysis_inhibitor  host_type_holin  host_type_spanin  \
# proteinID
# AB002632_00001                        NaN              NaN               NaN
# AB002632_00002                        NaN              NaN               NaN
# AB002632_00003                        NaN              NaN               NaN
# AB002632_00004                        NaN              NaN               NaN
# AB002632_00005                        NaN              NaN               NaN
# AB002632_00006                        NaN              NaN               NaN
# AB002632_00007                        NaN              NaN               NaN
# AB002632_00008                        NaN              NaN               NaN
# AB002632_00009                        NaN              NaN               NaN
# AB002632_00010                        NaN              NaN               NaN
#
#                 host_type_tail  host_type_pvp  host_type_DNA-associated
# proteinID
# AB002632_00001             NaN            NaN                  0.003104
# AB002632_00002             NaN            NaN                  0.139036
# AB002632_00003             NaN       0.793287                       NaN
# AB002632_00004             NaN            NaN                       NaN
# AB002632_00005             NaN       0.015858                       NaN
# AB002632_00006             NaN       0.001762                       NaN
# AB002632_00007             NaN       0.031803                       NaN
# AB002632_00008             NaN            NaN                       NaN
# AB002632_00009             NaN            NaN                       NaN
# AB002632_00010             NaN            NaN                  0.057654
#
# [10 rows x 40 columns]

# %%
random_splits_path = "../Data/all_random_pc_splits.pkl"
rs = pd.read_pickle(random_splits_path)

print("Random Splits File Shape:", rs.shape)
print(rs.head(10))
# Out:
# Random Splits File Shape: (1853074, 2160)
#                 split_Campylobacter_lysin  split_Campylobacter_endolysin  \
# proteinID
# AB002632_00001                       <NA>                           <NA>
# AB002632_00002                       <NA>                           <NA>
# AB002632_00003                       <NA>                           <NA>
# AB002632_00004                       <NA>                           <NA>
# AB002632_00005                       <NA>                           <NA>
# AB002632_00006                       <NA>                           <NA>
# AB002632_00007                       <NA>                           <NA>
# AB002632_00008                       <NA>                           <NA>
# AB002632_00009                       <NA>                           <NA>
# AB002632_00010                       <NA>                           <NA>
#
#                 split_Campylobacter_val  split_Caulobacter_lysin  \
# proteinID
# AB002632_00001                     <NA>                     <NA>
# AB002632_00002                     <NA>                     <NA>
# AB002632_00003                     <NA>                     <NA>
# AB002632_00004                     <NA>                     <NA>
# AB002632_00005                     <NA>                     <NA>
# AB002632_00006                     <NA>                     <NA>
# AB002632_00007                     <NA>                     <NA>
# AB002632_00008                     <NA>                     <NA>
# AB002632_00009                     <NA>                     <NA>
# AB002632_00010                     <NA>                     <NA>
#
#                 split_Caulobacter_endolysin  split_Caulobacter_val  \
# proteinID
# AB002632_00001                         <NA>                   <NA>
# AB002632_00002                         <NA>                   <NA>
# AB002632_00003                         <NA>                   <NA>
# AB002632_00004                         <NA>                   <NA>
# AB002632_00005                         <NA>                   <NA>
# AB002632_00006                         <NA>                   <NA>
# AB002632_00007                         <NA>                   <NA>
# AB002632_00008                         <NA>                   <NA>
# AB002632_00009                         <NA>                   <NA>
# AB002632_00010                         <NA>                   <NA>
#
#                 split_Cellulophaga_lysin  split_Cellulophaga_endolysin  \
# proteinID
# AB002632_00001                      <NA>                          <NA>
# AB002632_00002                      <NA>                          <NA>
# AB002632_00003                      <NA>                          <NA>
# AB002632_00004                      <NA>                          <NA>
# AB002632_00005                      <NA>                          <NA>
# AB002632_00006                      <NA>                          <NA>
# AB002632_00007                      <NA>                          <NA>
# AB002632_00008                      <NA>                          <NA>
# AB002632_00009                      <NA>                          <NA>
# AB002632_00010                      <NA>                          <NA>
#
#                 split_Cellulophaga_val  split_Citrobacter_lysin  ...  \
# proteinID                                                        ...
# AB002632_00001                    <NA>                     <NA>  ...
# AB002632_00002                    <NA>                     <NA>  ...
# AB002632_00003                    <NA>                     <NA>  ...
# AB002632_00004                    <NA>                     <NA>  ...
# AB002632_00005                    <NA>                     <NA>  ...
# AB002632_00006                    <NA>                     <NA>  ...
# AB002632_00007                    <NA>                     <NA>  ...
# AB002632_00008                    <NA>                     <NA>  ...
# AB002632_00009                    <NA>                     <NA>  ...
# AB002632_00010                    <NA>                     <NA>  ...
#
#                 split_Providencia_val  split_Serratia_lysin  \
# proteinID
# AB002632_00001                    NaN                   NaN
# AB002632_00002                    NaN                   NaN
# AB002632_00003                    NaN                   NaN
# AB002632_00004                    NaN                   NaN
# AB002632_00005                    NaN                   NaN
# AB002632_00006                    NaN                   NaN
# AB002632_00007                    NaN                   NaN
# AB002632_00008                    NaN                   NaN
# AB002632_00009                    NaN                   NaN
# AB002632_00010                    NaN                   NaN
#
#                 split_Serratia_endolysin  split_Serratia_val  \
# proteinID
# AB002632_00001                       NaN                 NaN
# AB002632_00002                       NaN                 NaN
# AB002632_00003                       NaN                 NaN
# AB002632_00004                       NaN                 NaN
# AB002632_00005                       NaN                 NaN
# AB002632_00006                       NaN                 NaN
# AB002632_00007                       NaN                 NaN
# AB002632_00008                       NaN                 NaN
# AB002632_00009                       NaN                 NaN
# AB002632_00010                       NaN                 NaN
#
#                 split_Pelagibacter_lysin  split_Pelagibacter_endolysin  \
# proteinID
# AB002632_00001                       NaN                           NaN
# AB002632_00002                       NaN                           NaN
# AB002632_00003                       NaN                           NaN
# AB002632_00004                       NaN                           NaN
# AB002632_00005                       NaN                           NaN
# AB002632_00006                       NaN                           NaN
# AB002632_00007                       NaN                           NaN
# AB002632_00008                       NaN                           NaN
# AB002632_00009                       NaN                           NaN
# AB002632_00010                       NaN                           NaN
#
#                 split_Pelagibacter_val  split_Shewanella_lysin  \
# proteinID
# AB002632_00001                     NaN                     NaN
# AB002632_00002                     NaN                     NaN
# AB002632_00003                     NaN                     NaN
# AB002632_00004                     NaN                     NaN
# AB002632_00005                     NaN                     NaN
# AB002632_00006                     NaN                     NaN
# AB002632_00007                     NaN                     NaN
# AB002632_00008                     NaN                     NaN
# AB002632_00009                     NaN                     NaN
# AB002632_00010                     NaN                     NaN
#
#                 split_Shewanella_endolysin  split_Shewanella_val
# proteinID
# AB002632_00001                         NaN                   NaN
# AB002632_00002                         NaN                   NaN
# AB002632_00003                         NaN                   NaN
# AB002632_00004                         NaN                   NaN
# AB002632_00005                         NaN                   NaN
# AB002632_00006                         NaN                   NaN
# AB002632_00007                         NaN                   NaN
# AB002632_00008                         NaN                   NaN
# AB002632_00009                         NaN                   NaN
# AB002632_00010                         NaN                   NaN
#
# [10 rows x 2160 columns]

# %%
import pickle
with open("../Data/all_random_pc_splits.pkl", "rb") as f:
    pc_splits = pickle.load(f)
print(type(pc_splits))
print(pc_splits.shape if hasattr(pc_splits, 'shape') else "not an array")
print(pc_splits)
# Out:
# <class 'pandas.DataFrame'>
# (1853074, 2160)
#                 split_Campylobacter_lysin  split_Campylobacter_endolysin  \
# proteinID
# AB002632_00001                       <NA>                           <NA>
# AB002632_00002                       <NA>                           <NA>
# AB002632_00003                       <NA>                           <NA>
# AB002632_00004                       <NA>                           <NA>
# AB002632_00005                       <NA>                           <NA>
# ...                                   ...                            ...
# Z47794_00023                         <NA>                           <NA>
# Z47794_00024                         <NA>                           <NA>
# Z47794_00025                         <NA>                           <NA>
# Z47794_00026                         <NA>                           <NA>
# Z47794_00027                         <NA>                           <NA>
#
#                 split_Campylobacter_val  split_Caulobacter_lysin  \
# proteinID
# AB002632_00001                     <NA>                     <NA>
# AB002632_00002                     <NA>                     <NA>
# AB002632_00003                     <NA>                     <NA>
# AB002632_00004                     <NA>                     <NA>
# AB002632_00005                     <NA>                     <NA>
# ...                                 ...                      ...
# Z47794_00023                       <NA>                     <NA>
# Z47794_00024                       <NA>                     <NA>
# Z47794_00025                       <NA>                     <NA>
# Z47794_00026                       <NA>                     <NA>
# Z47794_00027                       <NA>                     <NA>
#
#                 split_Caulobacter_endolysin  split_Caulobacter_val  \
# proteinID
# AB002632_00001                         <NA>                   <NA>
# AB002632_00002                         <NA>                   <NA>
# AB002632_00003                         <NA>                   <NA>
# AB002632_00004                         <NA>                   <NA>
# AB002632_00005                         <NA>                   <NA>
# ...                                     ...                    ...
# Z47794_00023                           <NA>                   <NA>
# Z47794_00024                           <NA>                   <NA>
# Z47794_00025                           <NA>                   <NA>
# Z47794_00026                           <NA>                   <NA>
# Z47794_00027                           <NA>                   <NA>
#
#                 split_Cellulophaga_lysin  split_Cellulophaga_endolysin  \
# proteinID
# AB002632_00001                      <NA>                          <NA>
# AB002632_00002                      <NA>                          <NA>
# AB002632_00003                      <NA>                          <NA>
# AB002632_00004                      <NA>                          <NA>
# AB002632_00005                      <NA>                          <NA>
# ...                                  ...                           ...
# Z47794_00023                        <NA>                          <NA>
# Z47794_00024                        <NA>                          <NA>
# Z47794_00025                        <NA>                          <NA>
# Z47794_00026                        <NA>                          <NA>
# Z47794_00027                        <NA>                          <NA>
#
#                 split_Cellulophaga_val  split_Citrobacter_lysin  ...  \
# proteinID                                                        ...
# AB002632_00001                    <NA>                     <NA>  ...
# AB002632_00002                    <NA>                     <NA>  ...
# AB002632_00003                    <NA>                     <NA>  ...
# AB002632_00004                    <NA>                     <NA>  ...
# AB002632_00005                    <NA>                     <NA>  ...
# ...                                ...                      ...  ...
# Z47794_00023                      <NA>                     <NA>  ...
# Z47794_00024                      <NA>                     <NA>  ...
# Z47794_00025                      <NA>                     <NA>  ...
# Z47794_00026                      <NA>                     <NA>  ...
# Z47794_00027                      <NA>                     <NA>  ...
#
#                 split_Providencia_val  split_Serratia_lysin  \
# proteinID
# AB002632_00001                    NaN                   NaN
# AB002632_00002                    NaN                   NaN
# AB002632_00003                    NaN                   NaN
# AB002632_00004                    NaN                   NaN
# AB002632_00005                    NaN                   NaN
# ...                               ...                   ...
# Z47794_00023                      NaN                   NaN
# Z47794_00024                      NaN                   NaN
# Z47794_00025                      NaN                   NaN
# Z47794_00026                      NaN                   NaN
# Z47794_00027                      NaN                   NaN
#
#                 split_Serratia_endolysin  split_Serratia_val  \
# proteinID
# AB002632_00001                       NaN                 NaN
# AB002632_00002                       NaN                 NaN
# AB002632_00003                       NaN                 NaN
# AB002632_00004                       NaN                 NaN
# AB002632_00005                       NaN                 NaN
# ...                                  ...                 ...
# Z47794_00023                         NaN                 NaN
# Z47794_00024                         NaN                 NaN
# Z47794_00025                         NaN                 NaN
# Z47794_00026                         NaN                 NaN
# Z47794_00027                         NaN                 NaN
#
#                 split_Pelagibacter_lysin  split_Pelagibacter_endolysin  \
# proteinID
# AB002632_00001                       NaN                           NaN
# AB002632_00002                       NaN                           NaN
# AB002632_00003                       NaN                           NaN
# AB002632_00004                       NaN                           NaN
# AB002632_00005                       NaN                           NaN
# ...                                  ...                           ...
# Z47794_00023                         NaN                           NaN
# Z47794_00024                         NaN                           NaN
# Z47794_00025                         NaN                           NaN
# Z47794_00026                         NaN                           NaN
# Z47794_00027                         NaN                           NaN
#
#                 split_Pelagibacter_val  split_Shewanella_lysin  \
# proteinID
# AB002632_00001                     NaN                     NaN
# AB002632_00002                     NaN                     NaN
# AB002632_00003                     NaN                     NaN
# AB002632_00004                     NaN                     NaN
# AB002632_00005                     NaN                     NaN
# ...                                ...                     ...
# Z47794_00023                       NaN                     NaN
# Z47794_00024                       NaN                     NaN
# Z47794_00025                       NaN                     NaN
# Z47794_00026                       NaN                     NaN
# Z47794_00027                       NaN                     NaN
#
#                 split_Shewanella_endolysin  split_Shewanella_val
# proteinID
# AB002632_00001                         NaN                   NaN
# AB002632_00002                         NaN                   NaN
# AB002632_00003                         NaN                   NaN
# AB002632_00004                         NaN                   NaN
# AB002632_00005                         NaN                   NaN
# ...                                    ...                   ...
# Z47794_00023                           NaN                   NaN
# Z47794_00024                           NaN                   NaN
# Z47794_00025                           NaN                   NaN
# Z47794_00026                           NaN                   NaN
# Z47794_00027                           NaN                   NaN
#
# [1853074 rows x 2160 columns]

# %%
# embeddings_path = "../Data/embeddings.pkl"
# em = pd.read_pickle(embeddings_path)

# print("Embeddings File Shape:", em.shape)
# print(em.head(10))

# %%
functional_predictions_path = "../Data/functional_predictions.pkl"
fp = pd.read_pickle(functional_predictions_path)

print("Functional Prediction File Shape:", fp.shape)
print(fp.head(10))
# Out:
# Functional Prediction File Shape: (1853074, 45)
#                    lysin  endolysin  val       pvp    capsid  major_capsid  \
# proteinID
# AB002632_00001  0.001376        NaN  NaN  0.046736       NaN           NaN
# AB002632_00002  0.000007        NaN  NaN  0.017311       NaN           NaN
# AB002632_00003  0.000215        NaN  NaN  0.582806  0.978879      0.008960
# AB002632_00004  0.000719        NaN  NaN  0.066260       NaN           NaN
# AB002632_00005  0.000038        NaN  NaN  0.995377  0.992280      0.999998
# AB002632_00006  0.000150        NaN  NaN  0.992850  0.979557      0.003570
# AB002632_00007  0.000129        NaN  NaN  0.990058  0.984072      0.004301
# AB002632_00008  0.000085        NaN  NaN  0.002115       NaN           NaN
# AB002632_00009  0.000063        NaN  NaN  0.021457       NaN           NaN
# AB002632_00010  0.000555        NaN  NaN  0.010502       NaN           NaN
#
#                 minor_capsid      tail  major_tail  minor_tail  ...  \
# proteinID                                                       ...
# AB002632_00001           NaN       NaN         NaN         NaN  ...
# AB002632_00002           NaN       NaN         NaN         NaN  ...
# AB002632_00003      0.973580  0.009338         NaN         NaN  ...
# AB002632_00004           NaN       NaN         NaN         NaN  ...
# AB002632_00005      0.001371  0.003364         NaN         NaN  ...
# AB002632_00006      0.992813  0.009344         NaN         NaN  ...
# AB002632_00007      0.993008  0.008110         NaN         NaN  ...
# AB002632_00008           NaN       NaN         NaN         NaN  ...
# AB002632_00009           NaN       NaN         NaN         NaN  ...
# AB002632_00010           NaN       NaN         NaN         NaN  ...
#
#                 reductase    crispr  anti-restriction      sir2     toxin  \
# proteinID
# AB002632_00001   0.000130  0.000006          0.000259  0.000022  0.000527
# AB002632_00002   0.000142  0.000012          0.001421  0.000008  0.000293
# AB002632_00003   0.000249  0.000016          0.000549  0.000012  0.000362
# AB002632_00004   0.000482  0.000011          0.000249  0.000026  0.000008
# AB002632_00005   0.001202  0.000026          0.000505  0.000005  0.000177
# AB002632_00006   0.000113  0.000008          0.000015  0.000029  0.003469
# AB002632_00007   0.000694  0.000021          0.000163  0.000010  0.000142
# AB002632_00008   0.001181  0.000022          0.000018  0.000001  0.977365
# AB002632_00009   0.000146  0.000002          0.000232  0.000116  0.000162
# AB002632_00010   0.000079  0.000076          0.000289  0.000042  0.002033
#
#                 super_infection     lysis  lysis_inhibitor  holin  spanin
# proteinID
# AB002632_00001         0.000142  0.002954              NaN    NaN     NaN
# AB002632_00002         0.000098  0.000421              NaN    NaN     NaN
# AB002632_00003         0.000266  0.090401              NaN    NaN     NaN
# AB002632_00004         0.000427  0.091976              NaN    NaN     NaN
# AB002632_00005         0.000623  0.016366              NaN    NaN     NaN
# AB002632_00006         0.002098  0.002762              NaN    NaN     NaN
# AB002632_00007         0.000639  0.007314              NaN    NaN     NaN
# AB002632_00008         0.000568  0.004320              NaN    NaN     NaN
# AB002632_00009         0.000804  0.007201              NaN    NaN     NaN
# AB002632_00010         0.000197  0.001508              NaN    NaN     NaN
#
# [10 rows x 45 columns]

# %%
from pathlib import Path

folder_path = Path("../Data/random_pc_r_5_da_2_bal")

# Print all files in the folder
for file in folder_path.iterdir():
    if file.is_file():
        print(file.name)
# Out:
# all_preds_grampos_terminase.pkl
# all_preds_grampos_adsorption-related.pkl
# all_preds_gramneg_spanin.pkl
# all_preds_gramneg_val.pkl
# all_preds_gramneg_cell_wall_depolymerase.pkl
# all_preds_gramneg_transcriptional_activator.pkl
# all_preds_gramneg_endolysin.pkl
# all_preds_gramneg_super_infection.pkl
# all_preds_grampos_transcriptional_repressor.pkl
# all_preds_gramneg_transcriptional_repressor.pkl
# all_preds_grampos_DNA_polymerase.pkl
# all_preds_grampos_nuclease.pkl
# all_preds_gramneg_DNA-associated_1.pkl
# all_preds_grampos_sir2.pkl
# all_preds_grampos_tail.pkl
# all_preds_gramneg_tail_sheath.pkl
# all_preds_gramneg_nucleotide_metabolism.pkl
# all_preds_grampos_spanin.pkl
# all_preds_grampos_integration.pkl
# all_preds_grampos_transferase.pkl
# all_preds_gramneg_nuclease.pkl
# all_preds_gramneg_replication_initiation.pkl
# all_preds_gramneg_reductase.pkl
# all_preds_grampos_nucleotide_metabolism.pkl
# all_preds_grampos_transcriptional_regulator.pkl
# all_preds_gramneg_integration.pkl
# all_preds_gramneg_lysis.pkl
# all_preds_gramneg_sir2.pkl
# all_preds_gramneg_adsorption-related.pkl
# all_preds_grampos_transcriptional_activator.pkl
# all_preds_grampos_tail_sheath.pkl
# all_preds_gramneg_tail.pkl
# all_preds_gramneg_pvp.pkl
# all_preds_gramneg_terminase.pkl
# all_preds_grampos_anti-restriction.pkl
# all_preds_grampos_DNA-associated.pkl
# all_preds_gramneg_holin.pkl
# all_scores_testset.csv
# all_preds_gramneg_primase.pkl
# all_preds_grampos_lysis_inhibitor.pkl
# all_preds_grampos_lysis.pkl
# all_preds_gramneg_baseplate.pkl
# all_preds_gramneg_ejection.pkl
# all_preds_gramneg_lysin.pkl
# all_preds_grampos_reductase.pkl
# all_preds_gramneg_transferase.pkl
# all_preds_grampos_portal.pkl
# all_preds_grampos_capsid.pkl
# all_preds_gramneg_annealing.pkl
# all_preds_grampos_endolysin.pkl
# all_preds_gramneg_transcriptional_regulator.pkl
# all_preds_grampos_head-tail_joining.pkl
# all_preds_gramneg_DNA_polymerase.pkl
# all_preds_gramneg_capsid.pkl
# all_preds_gramneg_anti-restriction.pkl
# all_preds_grampos_replication_initiation.pkl
# all_preds_grampos_val.pkl
# all_preds_gramneg_DNA-associated.pkl
# all_preds_grampos_super_infection.pkl
# all_preds_gramneg_portal.pkl
# all_preds_grampos_annealing.pkl
# all_preds_grampos_cell_wall_depolymerase.pkl
# all_preds_grampos_tail_appendage.pkl
# all_preds_gramneg_lysis_inhibitor.pkl
# all_preds_gramneg_helicase.pkl
# all_preds_gramneg_packaging_assembly.pkl
# all_preds_grampos_helicase.pkl
# all_preds_grampos_phosphorylation.pkl
# all_preds_gramneg_toxin.pkl
# all_preds_grampos_lysin.pkl
# all_preds_gramneg_head-tail_joining.pkl
# all_preds_grampos_RNA-associated.pkl
# all_preds_gramneg_phosphorylation.pkl
# all_preds_grampos_primase.pkl
# all_preds_grampos_toxin.pkl
# all_preds_grampos_ejection.pkl
# all_preds_grampos_pvp.pkl
# all_preds_grampos_holin.pkl
# all_scores_trainset.csv
# all_preds_gramneg_tail_appendage.pkl
# all_preds_grampos_baseplate.pkl
# all_preds_gramneg_RNA-associated.pkl
# all_preds_grampos_packaging_assembly.pkl

# %%
path1 = "../Data/random_pc_r_5_da_2_bal/all_preds_gramneg_lysin.pkl"
p1 = pd.read_pickle(path1)

print("File Shape:", p1.shape)
print(p1.head(10))
# Out:
# File Shape: (17703, 35)
#                 Microcystis_lysin  Escherichia_lysin  Klebsiella_lysin  \
# proteinID
# AB008550_00012           0.002003           0.005038          0.013542
# AB063393_00008           0.251198           0.004153          0.000678
# AB063393_00030           0.418809           0.000295          0.002559
# AB102868_00040           0.000289           0.214102          0.315367
# AB231700_00074           0.937293           0.008082          0.002237
# AB231700_00075           0.938319           0.005925          0.001559
# AB231700_00102           0.937351           0.035135          0.000294
# AB255436_00007           0.000125           0.922132          0.090454
# AB276040_00015           0.007102           0.006638          0.011640
# AB285204_00053           0.000298           0.112999          0.207087
#
#                 Edwardsiella_lysin  Flavobacterium_lysin  Erwinia_lysin  \
# proteinID
# AB008550_00012            0.034083              0.000190       0.020205
# AB063393_00008            0.022725              0.001417       0.000244
# AB063393_00030            0.050673              0.000105       0.000645
# AB102868_00040            0.103143              0.000176       0.007735
# AB231700_00074            0.057863              0.003076       0.001484
# AB231700_00075            0.084755              0.001244       0.003106
# AB231700_00102            0.050904              0.001247       0.000200
# AB255436_00007            0.172019              0.000121       0.002371
# AB276040_00015            0.045864              0.000032       0.007086
# AB285204_00053            0.112620              0.000162       0.011253
#
#                 Citrobacter_lysin  Campylobacter_lysin  Enterobacter_lysin  \
# proteinID
# AB008550_00012           0.002671             0.000059            0.020800
# AB063393_00008           0.000334             0.000329            0.008283
# AB063393_00030           0.000213             0.000109            0.003167
# AB102868_00040           0.020437             0.007703            0.020470
# AB231700_00074           0.000850             0.002157            0.010003
# AB231700_00075           0.001961             0.000088            0.009540
# AB231700_00102           0.000601             0.000978            0.005253
# AB255436_00007           0.002398             0.001256            0.018091
# AB276040_00015           0.002615             0.000055            0.017911
# AB285204_00053           0.015438             0.007299            0.013854
#
#                 Caulobacter_lysin  ...  Proteus_lysin  Rhizobium_lysin  \
# proteinID                          ...
# AB008550_00012           0.037538  ...       0.000385         0.000370
# AB063393_00008           0.017077  ...       0.000485         0.002795
# AB063393_00030           0.006774  ...       0.000452         0.002970
# AB102868_00040           0.009149  ...       0.001838         0.001338
# AB231700_00074           0.014696  ...       0.003007         0.049203
# AB231700_00075           0.074162  ...       0.000561         0.013970
# AB231700_00102           0.005428  ...       0.000983         0.194334
# AB255436_00007           0.002543  ...       0.004965         0.000289
# AB276040_00015           0.056740  ...       0.000224         0.000613
# AB285204_00053           0.008579  ...       0.001822         0.001581
#
#                 Stenotrophomonas_lysin  Pantoea_lysin  Rhodobacter_lysin  \
# proteinID
# AB008550_00012                0.007186       0.034514           0.000653
# AB063393_00008                0.378693       0.025940           0.001850
# AB063393_00030                0.017109       0.047320           0.000054
# AB102868_00040                0.007937       0.125501           0.000226
# AB231700_00074                0.008400       0.012279           0.000301
# AB231700_00075                0.014570       0.009178           0.000385
# AB231700_00102                0.052507       0.011223           0.002973
# AB255436_00007                0.004326       0.018369           0.000135
# AB276040_00015                0.007865       0.034583           0.002239
# AB285204_00053                0.006460       0.102928           0.000342
#
#                 Pectobacterium_lysin  Providencia_lysin  Serratia_lysin  \
# proteinID
# AB008550_00012              0.001935           0.002027        0.119088
# AB063393_00008              0.000377           0.005243        0.000616
# AB063393_00030              0.000520           0.000589        0.003067
# AB102868_00040              0.008137           0.186904        0.001368
# AB231700_00074              0.001317           0.002020        0.009449
# AB231700_00075              0.001092           0.001941        0.002271
# AB231700_00102              0.036420           0.010044        0.022528
# AB255436_00007              0.104536           0.396143        0.001309
# AB276040_00015              0.000736           0.002696        0.052185
# AB285204_00053              0.007945           0.157921        0.002490
#
#                 Pelagibacter_lysin  Shewanella_lysin
# proteinID
# AB008550_00012        3.457117e-05          0.694058
# AB063393_00008        9.378926e-07          0.001447
# AB063393_00030        1.000000e-07          0.026883
# AB102868_00040        6.135290e-07          0.000657
# AB231700_00074        8.285267e-06          0.035334
# AB231700_00075        5.206606e-06          0.313424
# AB231700_00102        1.728840e-06          0.000711
# AB255436_00007        1.111078e-05          0.000413
# AB276040_00015        4.168667e-06          0.611891
# AB285204_00053        5.728894e-07          0.001657
#
# [10 rows x 35 columns]

# %%
from pathlib import Path

folder_path = Path("../Data/random_pc_r10_dataaug_mgm_500")

# Print all files in the folder
for file in folder_path.iterdir():
    if file.is_file():
        print(file.name)
# Out:
# all_preds_grampos_terminase.pkl
# all_preds_grampos_adsorption-related.pkl
# all_preds_gramneg_spanin.pkl
# all_preds_gramneg_val.pkl
# all_preds_gramneg_cell_wall_depolymerase.pkl
# all_preds_gramneg_transcriptional_activator.pkl
# all_preds_gramneg_endolysin.pkl
# all_preds_gramneg_super_infection.pkl
# all_preds_grampos_transcriptional_repressor.pkl
# all_preds_gramneg_transcriptional_repressor.pkl
# all_preds_grampos_DNA_polymerase.pkl
# all_preds_grampos_nuclease.pkl
# all_preds_grampos_sir2.pkl
# all_preds_grampos_tail.pkl
# all_preds_gramneg_tail_sheath.pkl
# all_preds_gramneg_nucleotide_metabolism.pkl
# all_preds_grampos_spanin.pkl
# all_preds_grampos_integration.pkl
# all_preds_grampos_transferase.pkl
# all_preds_gramneg_nuclease.pkl
# all_preds_gramneg_replication_initiation.pkl
# all_preds_gramneg_reductase.pkl
# all_preds_grampos_nucleotide_metabolism.pkl
# all_preds_grampos_transcriptional_regulator.pkl
# all_preds_gramneg_integration.pkl
# all_preds_gramneg_lysis.pkl
# all_preds_gramneg_sir2.pkl
# general_trace.nc
# all_preds_gramneg_adsorption-related.pkl
# all_preds_grampos_transcriptional_activator.pkl
# all_preds_grampos_tail_sheath.pkl
# all_preds_gramneg_tail.pkl
# all_preds_gramneg_pvp.pkl
# all_preds_gramneg_terminase.pkl
# all_preds_grampos_anti-restriction.pkl
# all_preds_grampos_DNA-associated.pkl
# all_preds_gramneg_holin.pkl
# all_scores_testset.csv
# all_preds_gramneg_primase.pkl
# all_preds_grampos_lysis_inhibitor.pkl
# all_preds_grampos_lysis.pkl
# all_preds_gramneg_baseplate.pkl
# all_preds_gramneg_ejection.pkl
# all_preds_gramneg_lysin.pkl
# all_preds_grampos_reductase.pkl
# all_preds_gramneg_transferase.pkl
# all_preds_grampos_portal.pkl
# all_preds_grampos_capsid.pkl
# all_preds_gramneg_annealing.pkl
# all_preds_grampos_endolysin.pkl
# all_preds_gramneg_transcriptional_regulator.pkl
# all_preds_grampos_head-tail_joining.pkl
# all_preds_gramneg_DNA_polymerase.pkl
# all_preds_gramneg_capsid.pkl
# all_preds_gramneg_anti-restriction.pkl
# all_preds_grampos_replication_initiation.pkl
# all_preds_grampos_val.pkl
# all_preds_gramneg_DNA-associated.pkl
# all_preds_grampos_super_infection.pkl
# all_preds_gramneg_portal.pkl
# all_preds_grampos_annealing.pkl
# all_preds_grampos_cell_wall_depolymerase.pkl
# all_preds_grampos_tail_appendage.pkl
# all_preds_gramneg_lysis_inhibitor.pkl
# all_preds_gramneg_helicase.pkl
# all_preds_gramneg_packaging_assembly.pkl
# all_preds_grampos_helicase.pkl
# all_preds_grampos_phosphorylation.pkl
# all_preds_gramneg_toxin.pkl
# all_preds_grampos_lysin.pkl
# all_preds_gramneg_head-tail_joining.pkl
# all_preds_grampos_RNA-associated.pkl
# all_preds_gramneg_phosphorylation.pkl
# all_preds_grampos_primase.pkl
# all_preds_grampos_toxin.pkl
# all_preds_grampos_ejection.pkl
# all_preds_grampos_pvp.pkl
# all_preds_grampos_holin.pkl
# all_preds_gramneg_tail_appendage.pkl
# all_preds_grampos_baseplate.pkl
# all_preds_gramneg_RNA-associated.pkl
# all_preds_grampos_packaging_assembly.pkl

# %%
path2 = "../Data/random_pc_r10_dataaug_mgm_500/all_preds_gramneg_adsorption-related.pkl"
p2 = pd.read_pickle(path1)

print("File Shape:", p2.shape)
print(fp.head(10))
# Out:
# File Shape: (17703, 35)
#                    lysin  endolysin  val       pvp    capsid  major_capsid  \
# proteinID
# AB002632_00001  0.001376        NaN  NaN  0.046736       NaN           NaN
# AB002632_00002  0.000007        NaN  NaN  0.017311       NaN           NaN
# AB002632_00003  0.000215        NaN  NaN  0.582806  0.978879      0.008960
# AB002632_00004  0.000719        NaN  NaN  0.066260       NaN           NaN
# AB002632_00005  0.000038        NaN  NaN  0.995377  0.992280      0.999998
# AB002632_00006  0.000150        NaN  NaN  0.992850  0.979557      0.003570
# AB002632_00007  0.000129        NaN  NaN  0.990058  0.984072      0.004301
# AB002632_00008  0.000085        NaN  NaN  0.002115       NaN           NaN
# AB002632_00009  0.000063        NaN  NaN  0.021457       NaN           NaN
# AB002632_00010  0.000555        NaN  NaN  0.010502       NaN           NaN
#
#                 minor_capsid      tail  major_tail  minor_tail  ...  \
# proteinID                                                       ...
# AB002632_00001           NaN       NaN         NaN         NaN  ...
# AB002632_00002           NaN       NaN         NaN         NaN  ...
# AB002632_00003      0.973580  0.009338         NaN         NaN  ...
# AB002632_00004           NaN       NaN         NaN         NaN  ...
# AB002632_00005      0.001371  0.003364         NaN         NaN  ...
# AB002632_00006      0.992813  0.009344         NaN         NaN  ...
# AB002632_00007      0.993008  0.008110         NaN         NaN  ...
# AB002632_00008           NaN       NaN         NaN         NaN  ...
# AB002632_00009           NaN       NaN         NaN         NaN  ...
# AB002632_00010           NaN       NaN         NaN         NaN  ...
#
#                 reductase    crispr  anti-restriction      sir2     toxin  \
# proteinID
# AB002632_00001   0.000130  0.000006          0.000259  0.000022  0.000527
# AB002632_00002   0.000142  0.000012          0.001421  0.000008  0.000293
# AB002632_00003   0.000249  0.000016          0.000549  0.000012  0.000362
# AB002632_00004   0.000482  0.000011          0.000249  0.000026  0.000008
# AB002632_00005   0.001202  0.000026          0.000505  0.000005  0.000177
# AB002632_00006   0.000113  0.000008          0.000015  0.000029  0.003469
# AB002632_00007   0.000694  0.000021          0.000163  0.000010  0.000142
# AB002632_00008   0.001181  0.000022          0.000018  0.000001  0.977365
# AB002632_00009   0.000146  0.000002          0.000232  0.000116  0.000162
# AB002632_00010   0.000079  0.000076          0.000289  0.000042  0.002033
#
#                 super_infection     lysis  lysis_inhibitor  holin  spanin
# proteinID
# AB002632_00001         0.000142  0.002954              NaN    NaN     NaN
# AB002632_00002         0.000098  0.000421              NaN    NaN     NaN
# AB002632_00003         0.000266  0.090401              NaN    NaN     NaN
# AB002632_00004         0.000427  0.091976              NaN    NaN     NaN
# AB002632_00005         0.000623  0.016366              NaN    NaN     NaN
# AB002632_00006         0.002098  0.002762              NaN    NaN     NaN
# AB002632_00007         0.000639  0.007314              NaN    NaN     NaN
# AB002632_00008         0.000568  0.004320              NaN    NaN     NaN
# AB002632_00009         0.000804  0.007201              NaN    NaN     NaN
# AB002632_00010         0.000197  0.001508              NaN    NaN     NaN
#
# [10 rows x 45 columns]

# %%
p1 = pd.read_pickle("../Data/random_pc_r_5_da_2_bal/all_preds_gramneg_lysin.pkl")
print("r5 gramneg lysin shape:", p1.shape)
print(p1.head(3))
print()
# Out:
# r5 gramneg lysin shape: (17703, 35)
#                 Microcystis_lysin  Escherichia_lysin  Klebsiella_lysin  \
# proteinID
# AB008550_00012           0.002003           0.005038          0.013542
# AB063393_00008           0.251198           0.004153          0.000678
# AB063393_00030           0.418809           0.000295          0.002559
#
#                 Edwardsiella_lysin  Flavobacterium_lysin  Erwinia_lysin  \
# proteinID
# AB008550_00012            0.034083              0.000190       0.020205
# AB063393_00008            0.022725              0.001417       0.000244
# AB063393_00030            0.050673              0.000105       0.000645
#
#                 Citrobacter_lysin  Campylobacter_lysin  Enterobacter_lysin  \
# proteinID
# AB008550_00012           0.002671             0.000059            0.020800
# AB063393_00008           0.000334             0.000329            0.008283
# AB063393_00030           0.000213             0.000109            0.003167
#
#                 Caulobacter_lysin  ...  Proteus_lysin  Rhizobium_lysin  \
# proteinID                          ...
# AB008550_00012           0.037538  ...       0.000385         0.000370
# AB063393_00008           0.017077  ...       0.000485         0.002795
# AB063393_00030           0.006774  ...       0.000452         0.002970
#
#                 Stenotrophomonas_lysin  Pantoea_lysin  Rhodobacter_lysin  \
# proteinID
# AB008550_00012                0.007186       0.034514           0.000653
# AB063393_00008                0.378693       0.025940           0.001850
# AB063393_00030                0.017109       0.047320           0.000054
#
#                 Pectobacterium_lysin  Providencia_lysin  Serratia_lysin  \
# proteinID
# AB008550_00012              0.001935           0.002027        0.119088
# AB063393_00008              0.000377           0.005243        0.000616
# AB063393_00030              0.000520           0.000589        0.003067
#
#                 Pelagibacter_lysin  Shewanella_lysin
# proteinID
# AB008550_00012        3.457117e-05          0.694058
# AB063393_00008        9.378926e-07          0.001447
# AB063393_00030        1.000000e-07          0.026883
#
# [3 rows x 35 columns]

# %%
p2 = pd.read_pickle("../Data/random_pc_r10_dataaug_mgm_500/all_preds_gramneg_lysin.pkl")
print("r10 gramneg lysin shape:", p2.shape)
print(p2.head(3))
# Out:
# r10 gramneg lysin shape: (17703, 13)
#                 Microcystis_lysin  Escherichia_lysin  Klebsiella_lysin  \
# proteinID
# AB008550_00012           0.001947           0.006910          0.061624
# AB063393_00008           0.000034           0.013609          0.019631
# AB063393_00030           0.004926           0.004297          0.058380
#
#                 Edwardsiella_lysin  Flavobacterium_lysin  Erwinia_lysin  \
# proteinID
# AB008550_00012        2.573139e-03              0.000022       0.017297
# AB063393_00008        1.000000e-07              0.000003       0.000017
# AB063393_00030        9.810779e-06              0.000004       0.000800
#
#                 Citrobacter_lysin  Campylobacter_lysin  Enterobacter_lysin  \
# proteinID
# AB008550_00012       1.315590e-02             0.000534        1.460216e-02
# AB063393_00008       4.707559e-07             0.000048        2.253697e-07
# AB063393_00030       4.467043e-05             0.000308        2.464745e-05
#
#                 Caulobacter_lysin  Dickeya_lysin  Cronobacter_lysin  \
# proteinID
# AB008550_00012           0.019528   7.850282e-03           0.022648
# AB063393_00008           0.000002   1.000000e-07           0.000001
# AB063393_00030           0.000215   1.185190e-06           0.000068
#
#                 Cellulophaga_lysin
# proteinID
# AB008550_00012            0.000036
# AB063393_00008            0.000002
# AB063393_00030            0.000022

# %%
train_scores = pd.read_csv("../Data/random_pc_r_5_da_2_bal/all_scores_trainset.csv", index_col=0, nrows=5)
print("trainset shape columns:", train_scores.shape)
print(train_scores.head(3))
print()
# Out:
# trainset shape columns: (5, 5)
#                          f1-score  precision    recall  accuracy  bal_accuracy
# Campylobacter_lysin      0.318021   0.192582  0.912162  0.963479      0.938062
# Campylobacter_endolysin  0.453488   0.327731  0.735849  0.978648      0.858728
# Campylobacter_val        0.188312   0.105455  0.878788  0.940912      0.910094

# %%
test_scores = pd.read_csv("../Data/random_pc_r_5_da_2_bal/all_scores_testset.csv", index_col=0, nrows=5)
print("testset shape:", test_scores.shape)
print(test_scores.head(3))
# Out:
# testset shape: (5, 5)
#                          f1-score  precision    recall  accuracy  bal_accuracy
# Campylobacter_lysin      0.000000        0.0  0.000000  0.987020      0.500000
# Campylobacter_endolysin  0.000000        0.0  0.000000  0.999063      0.500000
# Campylobacter_val        0.909091        1.0  0.833333  0.996580      0.916667

# %%
cols = pc_splits.columns.tolist()
print(cols[:20])  # just first 20 raw column names
# Out:
# ['split_Campylobacter_lysin', 'split_Campylobacter_endolysin', 'split_Campylobacter_val', 'split_Caulobacter_lysin', 'split_Caulobacter_endolysin', 'split_Caulobacter_val', 'split_Cellulophaga_lysin', 'split_Cellulophaga_endolysin', 'split_Cellulophaga_val', 'split_Citrobacter_lysin', 'split_Citrobacter_endolysin', 'split_Citrobacter_val', 'split_Clostridioides_lysin', 'split_Clostridioides_endolysin', 'split_Clostridioides_val', 'split_Clostridium_lysin', 'split_Clostridium_endolysin', 'split_Clostridium_val', 'split_Corynebacterium_lysin', 'split_Corynebacterium_endolysin']

# %%
from pathlib import Path

folder_path = Path("../Data/random_pc_r_5_da_2_bal_s_0")

# Print all files in the folder
for file in folder_path.iterdir():
    if file.is_file():
        print(file.name)
# Out:
# all_preds_grampos_terminase.pkl
# all_preds_grampos_adsorption-related.pkl
# all_preds_gramneg_spanin.pkl
# all_preds_gramneg_val.pkl
# all_preds_gramneg_cell_wall_depolymerase.pkl
# all_preds_gramneg_transcriptional_activator.pkl
# all_preds_gramneg_endolysin.pkl
# all_preds_gramneg_super_infection.pkl
# all_preds_grampos_transcriptional_repressor.pkl
# all_preds_gramneg_transcriptional_repressor.pkl
# all_preds_grampos_DNA_polymerase.pkl
# all_preds_grampos_nuclease.pkl
# all_preds_gramneg_DNA-associated_1.pkl
# all_preds_grampos_sir2.pkl
# all_preds_grampos_tail.pkl
# all_preds_gramneg_tail_sheath.pkl
# all_preds_gramneg_nucleotide_metabolism.pkl
# all_preds_grampos_spanin.pkl
# all_preds_grampos_integration.pkl
# all_preds_grampos_transferase.pkl
# all_preds_gramneg_nuclease.pkl
# all_preds_gramneg_replication_initiation.pkl
# all_preds_gramneg_reductase.pkl
# all_preds_grampos_nucleotide_metabolism.pkl
# all_preds_grampos_transcriptional_regulator.pkl
# all_preds_gramneg_integration.pkl
# all_preds_gramneg_lysis.pkl
# all_preds_gramneg_sir2.pkl
# all_preds_gramneg_adsorption-related.pkl
# all_preds_grampos_transcriptional_activator.pkl
# all_preds_grampos_tail_sheath.pkl
# all_preds_gramneg_tail.pkl
# all_preds_gramneg_pvp.pkl
# all_preds_gramneg_terminase.pkl
# all_preds_grampos_anti-restriction.pkl
# all_preds_grampos_DNA-associated.pkl
# all_preds_gramneg_holin.pkl
# all_scores_testset.csv
# all_preds_gramneg_primase.pkl
# all_preds_grampos_lysis_inhibitor.pkl
# all_preds_grampos_lysis.pkl
# all_preds_gramneg_baseplate.pkl
# all_preds_gramneg_ejection.pkl
# all_preds_gramneg_lysin.pkl
# all_preds_grampos_reductase.pkl
# all_preds_gramneg_transferase.pkl
# all_preds_grampos_portal.pkl
# all_preds_grampos_capsid.pkl
# all_preds_gramneg_annealing.pkl
# all_preds_grampos_endolysin.pkl
# all_preds_gramneg_transcriptional_regulator.pkl
# all_preds_grampos_head-tail_joining.pkl
# all_preds_gramneg_DNA_polymerase.pkl
# all_preds_gramneg_capsid.pkl
# all_preds_gramneg_anti-restriction.pkl
# all_preds_grampos_replication_initiation.pkl
# all_preds_grampos_val.pkl
# all_preds_gramneg_DNA-associated.pkl
# all_preds_grampos_super_infection.pkl
# all_preds_gramneg_portal.pkl
# all_preds_grampos_annealing.pkl
# all_preds_grampos_cell_wall_depolymerase.pkl
# all_preds_grampos_tail_appendage.pkl
# all_preds_gramneg_lysis_inhibitor.pkl
# all_preds_gramneg_helicase.pkl
# all_preds_gramneg_packaging_assembly.pkl
# all_preds_grampos_helicase.pkl
# all_preds_grampos_phosphorylation.pkl
# all_preds_gramneg_toxin.pkl
# all_preds_grampos_lysin.pkl
# all_preds_gramneg_head-tail_joining.pkl
# all_preds_grampos_RNA-associated.pkl
# all_preds_gramneg_phosphorylation.pkl
# all_preds_grampos_primase.pkl
# all_preds_grampos_toxin.pkl
# all_preds_grampos_ejection.pkl
# all_preds_grampos_pvp.pkl
# all_preds_grampos_holin.pkl
# all_scores_trainset.csv
# all_preds_gramneg_tail_appendage.pkl
# all_preds_grampos_baseplate.pkl
# all_preds_gramneg_RNA-associated.pkl
# all_preds_grampos_packaging_assembly.pkl

# %%
import pandas as pd
p1 = pd.read_pickle("../Data/random_pc_r_5_da_2_bal_s_0/all_preds_grampos_spanin.pkl")
print("Split 0 - Spanin:", p1.shape)
print(p1.head(10))
# Out:
# Split 0 - Spanin: (368, 8)
#                        Staphylococcus_spanin  Enterococcus_spanin  \
# proteinID
# AB605730_00006                      0.012763             0.001122
# AY129336_00036                      0.008955             0.004116
# AY129339_00038                      0.012793             0.018749
# AY576796_00035                      0.025181             0.002874
# CAJCJZ010000002_00052               0.011199             0.990207
# CAJDJX010000002_00052               0.009234             0.992130
# CAJDKF010000002_00052               0.012772             0.992862
# EU744250_00078                      0.009358             0.006905
# FM163528_00029                      0.008549             0.018712
# GU169904_00016                      0.934444             0.011573
#
#                        Mycobacterium_spanin  Streptococcus_spanin  \
# proteinID
# AB605730_00006                     0.000007              0.183506
# AY129336_00036                     0.984863              0.011113
# AY129339_00038                     0.984685              0.007453
# AY576796_00035                     0.042156              0.004056
# CAJCJZ010000002_00052              0.000032              0.016572
# CAJDJX010000002_00052              0.000003              0.005886
# CAJDKF010000002_00052              0.000002              0.002768
# EU744250_00078                     0.994234              0.011946
# FM163528_00029                     0.000017              0.990984
# GU169904_00016                     0.000210              0.011087
#
#                        Streptomyces_spanin  Paenibacillus_spanin  \
# proteinID
# AB605730_00006                    0.013118              0.082190
# AY129336_00036                    0.000760              0.051490
# AY129339_00038                    0.001548              0.060768
# AY576796_00035                    0.004726              0.038229
# CAJCJZ010000002_00052             0.001293              0.024601
# CAJDJX010000002_00052             0.000924              0.025649
# CAJDKF010000002_00052             0.001183              0.026192
# EU744250_00078                    0.007330              0.020149
# FM163528_00029                    0.000943              0.083607
# GU169904_00016                    0.000841              0.020834
#
#                        Microbacterium_spanin  Gordonia_spanin
# proteinID
# AB605730_00006                      0.008441         0.009707
# AY129336_00036                      0.004287         0.004872
# AY129339_00038                      0.000669         0.006518
# AY576796_00035                      0.002607         0.008629
# CAJCJZ010000002_00052               0.000869         0.002215
# CAJDJX010000002_00052               0.000743         0.003732
# CAJDKF010000002_00052               0.000677         0.004523
# EU744250_00078                      0.002524         0.009721
# FM163528_00029                      0.000983         0.003036
# GU169904_00016                      0.001787         0.481903

# %%
import pandas as pd
p1 = pd.read_pickle("../Data/random_pc_r_5_da_2_bal_s_0/all_preds_grampos_terminase.pkl")
print("Split 0 - Terminase", p1.shape)
print(p1.head(10))
print()
# Out:
# Split 0 - Terminase (18726, 16)
#                 Staphylococcus_terminase  Enterococcus_terminase  \
# proteinID
# AB009866_00001                  0.984776                0.165573
# AB009866_00002                  0.951542                0.071762
# AB016282_00001                  0.006609                0.001898
# AB016282_00002                  0.006087                0.085527
# AB016282_00003                  0.028551                0.001127
# AB044554_00040                  0.984776                0.165573
# AB044554_00041                  0.963615                0.070279
# AB045978_00042                  0.901666                0.000017
# AB045978_00043                  0.973661                0.028315
# AB243556_00041                  0.984776                0.165573
#
#                 Clostridium_terminase  Lactococcus_terminase  \
# proteinID
# AB009866_00001               0.027331               0.001091
# AB009866_00002               0.000073               0.002010
# AB016282_00001               0.009548               0.001902
# AB016282_00002               0.000180               0.000015
# AB016282_00003               0.000048               0.002376
# AB044554_00040               0.027331               0.001091
# AB044554_00041               0.000082               0.001467
# AB045978_00042               0.023099               0.006088
# AB045978_00043               0.028317               0.000021
# AB243556_00041               0.027331               0.001091
#
#                 Mycobacterium_terminase  Streptococcus_terminase  \
# proteinID
# AB009866_00001             1.017577e-05                 0.001865
# AB009866_00002             1.000000e-07                 0.003553
# AB016282_00001             1.443280e-04                 0.004432
# AB016282_00002             1.000000e-07                 0.061092
# AB016282_00003             1.500807e-07                 0.010613
# AB044554_00040             1.017577e-05                 0.001865
# AB044554_00041             1.000000e-07                 0.003419
# AB045978_00042             2.674604e-06                 0.956432
# AB045978_00043             1.000000e-07                 0.000871
# AB243556_00041             1.017577e-05                 0.001865
#
#                 Lactobacillus_terminase  Propionibacterium_terminase  \
# proteinID
# AB009866_00001                 0.000180                     0.000540
# AB009866_00002                 0.610094                     0.000705
# AB016282_00001                 0.014436                     0.004075
# AB016282_00002                 0.027427                     0.000439
# AB016282_00003                 0.011556                     0.000104
# AB044554_00040                 0.000180                     0.000540
# AB044554_00041                 0.559410                     0.000687
# AB045978_00042                 0.003243                     0.002489
# AB045978_00043                 0.002979                     0.000096
# AB243556_00041                 0.000180                     0.000540
#
#                 Listeria_terminase  Corynebacterium_terminase  \
# proteinID
# AB009866_00001            0.000111                   0.000887
# AB009866_00002            0.000126                   0.001356
# AB016282_00001            0.000440                   0.001247
# AB016282_00002            0.000749                   0.002679
# AB016282_00003            0.000460                   0.001266
# AB044554_00040            0.000111                   0.000887
# AB044554_00041            0.000122                   0.001374
# AB045978_00042            0.000119                   0.000104
# AB045978_00043            0.000145                   0.001583
# AB243556_00041            0.000111                   0.000887
#
#                 Streptomyces_terminase  Paenibacillus_terminase  \
# proteinID
# AB009866_00001                0.000008                 0.020098
# AB009866_00002                0.000021                 0.010583
# AB016282_00001                0.000041                 0.115326
# AB016282_00002                0.000664                 0.196614
# AB016282_00003                0.000039                 0.000283
# AB044554_00040                0.000008                 0.020098
# AB044554_00041                0.000023                 0.013215
# AB045978_00042                0.000001                 0.530117
# AB045978_00043                0.000024                 0.879484
# AB243556_00041                0.000008                 0.020098
#
#                 Clostridioides_terminase  Microbacterium_terminase  \
# proteinID
# AB009866_00001                  0.000821              3.356033e-07
# AB009866_00002                  0.004573              1.969378e-06
# AB016282_00001                  0.000209              1.157825e-06
# AB016282_00002                  0.003507              9.524341e-06
# AB016282_00003                  0.000290              1.202348e-05
# AB044554_00040                  0.000821              3.356033e-07
# AB044554_00041                  0.004846              1.780704e-06
# AB045978_00042                  0.042646              2.193154e-05
# AB045978_00043                  0.043424              4.772785e-07
# AB243556_00041                  0.000821              3.356033e-07
#
#                 Gordonia_terminase  Lacticaseibacillus_terminase
# proteinID
# AB009866_00001            0.001610                      0.042168
# AB009866_00002            0.000315                      0.177807
# AB016282_00001            0.000213                      0.157942
# AB016282_00002            0.000145                      0.004623
# AB016282_00003            0.000374                      0.001261
# AB044554_00040            0.001610                      0.042168
# AB044554_00041            0.000256                      0.165684
# AB045978_00042            0.000263                      0.003228
# AB045978_00043            0.000164                      0.002365
# AB243556_00041            0.001610                      0.042168

# %%
from pathlib import Path

folder_path = Path("../Data/random_pc_r_5_da_2_bal_s_1")

# Print all files in the folder
for file in folder_path.iterdir():
    if file.is_file():
        print(file.name)
# Out:
# all_preds_grampos_terminase.pkl
# all_preds_grampos_adsorption-related.pkl
# all_preds_gramneg_spanin.pkl
# all_preds_gramneg_val.pkl
# all_preds_gramneg_cell_wall_depolymerase.pkl
# all_preds_gramneg_transcriptional_activator.pkl
# all_preds_gramneg_endolysin.pkl
# all_preds_gramneg_super_infection.pkl
# all_preds_grampos_transcriptional_repressor.pkl
# all_preds_gramneg_transcriptional_repressor.pkl
# all_preds_grampos_DNA_polymerase.pkl
# all_preds_grampos_nuclease.pkl
# all_preds_grampos_sir2.pkl
# all_preds_grampos_tail.pkl
# all_preds_gramneg_tail_sheath.pkl
# all_preds_gramneg_nucleotide_metabolism.pkl
# all_preds_grampos_spanin.pkl
# all_preds_grampos_integration.pkl
# all_preds_grampos_transferase.pkl
# all_preds_gramneg_nuclease.pkl
# all_preds_gramneg_replication_initiation.pkl
# all_preds_gramneg_reductase.pkl
# all_preds_grampos_nucleotide_metabolism.pkl
# all_preds_grampos_transcriptional_regulator.pkl
# all_preds_gramneg_integration.pkl
# all_preds_gramneg_lysis.pkl
# all_preds_gramneg_sir2.pkl
# all_preds_gramneg_adsorption-related.pkl
# all_preds_grampos_transcriptional_activator.pkl
# all_preds_grampos_tail_sheath.pkl
# all_preds_gramneg_tail.pkl
# all_preds_gramneg_pvp.pkl
# all_preds_gramneg_terminase.pkl
# all_preds_grampos_anti-restriction.pkl
# all_preds_grampos_DNA-associated.pkl
# all_preds_gramneg_holin.pkl
# all_preds_gramneg_primase.pkl
# all_preds_grampos_lysis_inhibitor.pkl
# all_preds_grampos_lysis.pkl
# all_preds_gramneg_baseplate.pkl
# all_preds_gramneg_ejection.pkl
# all_preds_gramneg_lysin.pkl
# all_preds_grampos_reductase.pkl
# all_preds_gramneg_transferase.pkl
# all_preds_grampos_portal.pkl
# all_preds_grampos_capsid.pkl
# all_preds_gramneg_annealing.pkl
# all_preds_grampos_endolysin.pkl
# all_preds_gramneg_transcriptional_regulator.pkl
# all_preds_grampos_head-tail_joining.pkl
# all_preds_gramneg_DNA_polymerase.pkl
# all_preds_gramneg_capsid.pkl
# all_preds_gramneg_anti-restriction.pkl
# all_preds_grampos_replication_initiation.pkl
# all_preds_grampos_val.pkl
# all_preds_gramneg_DNA-associated.pkl
# all_preds_grampos_super_infection.pkl
# all_preds_gramneg_portal.pkl
# all_preds_grampos_annealing.pkl
# all_preds_grampos_cell_wall_depolymerase.pkl
# all_preds_grampos_tail_appendage.pkl
# all_preds_gramneg_lysis_inhibitor.pkl
# all_preds_gramneg_helicase.pkl
# all_preds_gramneg_packaging_assembly.pkl
# all_preds_grampos_helicase.pkl
# all_preds_grampos_phosphorylation.pkl
# all_preds_gramneg_toxin.pkl
# all_preds_grampos_lysin.pkl
# all_preds_gramneg_head-tail_joining.pkl
# all_preds_grampos_RNA-associated.pkl
# all_preds_gramneg_phosphorylation.pkl
# all_preds_grampos_primase.pkl
# all_preds_grampos_toxin.pkl
# all_preds_grampos_ejection.pkl
# all_preds_grampos_pvp.pkl
# all_preds_grampos_holin.pkl
# all_preds_gramneg_tail_appendage.pkl
# all_preds_grampos_baseplate.pkl
# all_preds_gramneg_RNA-associated.pkl
# all_preds_grampos_packaging_assembly.pkl

# %%
import pandas as pd
p1 = pd.read_pickle("../Data/random_pc_r_5_da_2_bal_s_1/all_preds_grampos_terminase.pkl")
print("Split 1 - Terminase:", p1.shape)
print(p1.head(3))
print()
# Out:
# Split 1 - Terminase: (18726, 16)
#                 Staphylococcus_terminase  Enterococcus_terminase  \
# proteinID
# AB009866_00001                  0.960548                0.909849
# AB009866_00002                  0.432728                0.113091
# AB016282_00001                  0.047591                0.078826
#
#                 Clostridium_terminase  Lactococcus_terminase  \
# proteinID
# AB009866_00001               0.040532               0.000154
# AB009866_00002               0.000113               0.001350
# AB016282_00001               0.012649               0.000266
#
#                 Mycobacterium_terminase  Streptococcus_terminase  \
# proteinID
# AB009866_00001             1.989932e-05                 0.000790
# AB009866_00002             7.731400e-07                 0.005330
# AB016282_00001             5.949147e-04                 0.001255
#
#                 Lactobacillus_terminase  Propionibacterium_terminase  \
# proteinID
# AB009866_00001                 0.000304                     0.000204
# AB009866_00002                 0.261903                     0.000029
# AB016282_00001                 0.021145                     0.000589
#
#                 Listeria_terminase  Corynebacterium_terminase  \
# proteinID
# AB009866_00001            0.000025                   0.006351
# AB009866_00002            0.000009                   0.005532
# AB016282_00001            0.000047                   0.006052
#
#                 Streptomyces_terminase  Paenibacillus_terminase  \
# proteinID
# AB009866_00001                0.000013                 0.200009
# AB009866_00002                0.000009                 0.248740
# AB016282_00001                0.000022                 0.277654
#
#                 Clostridioides_terminase  Microbacterium_terminase  \
# proteinID
# AB009866_00001                  0.000802              1.000000e-07
# AB009866_00002                  0.000970              1.000000e-07
# AB016282_00001                  0.000469              1.000000e-07
#
#                 Gordonia_terminase  Lacticaseibacillus_terminase
# proteinID
# AB009866_00001            0.000287                      0.212301
# AB009866_00002            0.000380                      0.493326
# AB016282_00001            0.000047                      0.160945

# %%
p2 = pd.read_pickle("../Data/random_pc_r_5_da_2_bal_s_1/all_preds_grampos_spanin.pkl")
print("Split 1 - Spanin", p2.shape)
print(p2.head(10))
print()
# Out:
# Split 1 - Spanin (368, 8)
#                        Staphylococcus_spanin  Enterococcus_spanin  \
# proteinID
# AB605730_00006                      0.007392             0.000485
# AY129336_00036                      0.013316             0.003830
# AY129339_00038                      0.039275             0.003831
# AY576796_00035                      0.013996             0.000910
# CAJCJZ010000002_00052               0.012026             0.963149
# CAJDJX010000002_00052               0.042411             0.026122
# CAJDKF010000002_00052               0.070577             0.035317
# EU744250_00078                      0.007129             0.003370
# FM163528_00029                      0.012017             0.003835
# GU169904_00016                      0.967147             0.002134
#
#                        Mycobacterium_spanin  Streptococcus_spanin  \
# proteinID
# AB605730_00006                 8.583578e-05              0.065344
# AY129336_00036                 9.726445e-01              0.009724
# AY129339_00038                 9.718922e-01              0.005585
# AY576796_00035                 2.543893e-02              0.001838
# CAJCJZ010000002_00052          9.733811e-07              0.022907
# CAJDJX010000002_00052          5.429448e-07              0.004860
# CAJDKF010000002_00052          1.000000e-07              0.004579
# EU744250_00078                 9.864612e-01              0.007673
# FM163528_00029                 2.363865e-06              0.977855
# GU169904_00016                 4.243826e-04              0.023957
#
#                        Streptomyces_spanin  Paenibacillus_spanin  \
# proteinID
# AB605730_00006                    0.006984              0.085366
# AY129336_00036                    0.000544              0.032499
# AY129339_00038                    0.000246              0.057229
# AY576796_00035                    0.003368              0.040048
# CAJCJZ010000002_00052             0.000065              0.023660
# CAJDJX010000002_00052             0.000570              0.021912
# CAJDKF010000002_00052             0.000686              0.026840
# EU744250_00078                    0.001543              0.021985
# FM163528_00029                    0.000548              0.075787
# GU169904_00016                    0.000671              0.019437
#
#                        Microbacterium_spanin  Gordonia_spanin
# proteinID
# AB605730_00006                      0.012880         0.003002
# AY129336_00036                      0.015305         0.060139
# AY129339_00038                      0.001787         0.003517
# AY576796_00035                      0.037680         0.005905
# CAJCJZ010000002_00052               0.001031         0.001196
# CAJDJX010000002_00052               0.000677         0.003189
# CAJDKF010000002_00052               0.000375         0.002364
# EU744250_00078                      0.003354         0.018015
# FM163528_00029                      0.000627         0.002436
# GU169904_00016                      0.002844         0.448582

# %%
folder_path = Path("../Data/random_pc_r_5_da_2_bal_s_2")

# Print all files in the folder
for file in folder_path.iterdir():
    if file.is_file():
        print(file.name)
# Out:
# all_preds_grampos_terminase.pkl
# all_preds_grampos_adsorption-related.pkl
# all_preds_gramneg_spanin.pkl
# all_preds_gramneg_val.pkl
# all_preds_gramneg_cell_wall_depolymerase.pkl
# all_preds_gramneg_transcriptional_activator.pkl
# all_preds_gramneg_endolysin.pkl
# all_preds_gramneg_super_infection.pkl
# all_preds_grampos_transcriptional_repressor.pkl
# all_preds_gramneg_transcriptional_repressor.pkl
# all_preds_grampos_DNA_polymerase.pkl
# all_preds_grampos_nuclease.pkl
# all_preds_grampos_sir2.pkl
# all_preds_grampos_tail.pkl
# all_preds_gramneg_tail_sheath.pkl
# all_preds_gramneg_nucleotide_metabolism.pkl
# all_preds_grampos_spanin.pkl
# all_preds_grampos_integration.pkl
# all_preds_grampos_transferase.pkl
# all_preds_gramneg_nuclease.pkl
# all_preds_gramneg_replication_initiation.pkl
# all_preds_gramneg_reductase.pkl
# all_preds_grampos_nucleotide_metabolism.pkl
# all_preds_grampos_transcriptional_regulator.pkl
# all_preds_gramneg_integration.pkl
# all_preds_gramneg_lysis.pkl
# all_preds_gramneg_sir2.pkl
# all_preds_gramneg_adsorption-related.pkl
# all_preds_grampos_transcriptional_activator.pkl
# all_preds_grampos_tail_sheath.pkl
# all_preds_gramneg_tail.pkl
# all_preds_gramneg_pvp.pkl
# all_preds_gramneg_terminase.pkl
# all_preds_grampos_anti-restriction.pkl
# all_preds_grampos_DNA-associated.pkl
# all_preds_gramneg_holin.pkl
# all_preds_gramneg_primase.pkl
# all_preds_grampos_lysis_inhibitor.pkl
# all_preds_grampos_lysis.pkl
# all_preds_gramneg_baseplate.pkl
# all_preds_gramneg_ejection.pkl
# all_preds_gramneg_lysin.pkl
# all_preds_grampos_reductase.pkl
# all_preds_gramneg_transferase.pkl
# all_preds_grampos_portal.pkl
# all_preds_grampos_capsid.pkl
# all_preds_gramneg_annealing.pkl
# all_preds_grampos_endolysin.pkl
# all_preds_gramneg_transcriptional_regulator.pkl
# all_preds_grampos_head-tail_joining.pkl
# all_preds_gramneg_DNA_polymerase.pkl
# all_preds_gramneg_capsid.pkl
# all_preds_gramneg_anti-restriction.pkl
# all_preds_grampos_replication_initiation.pkl
# all_preds_grampos_val.pkl
# all_preds_gramneg_DNA-associated.pkl
# all_preds_grampos_super_infection.pkl
# all_preds_gramneg_portal.pkl
# all_preds_grampos_annealing.pkl
# all_preds_grampos_cell_wall_depolymerase.pkl
# all_preds_grampos_tail_appendage.pkl
# all_preds_gramneg_lysis_inhibitor.pkl
# all_preds_gramneg_helicase.pkl
# all_preds_gramneg_packaging_assembly.pkl
# all_preds_grampos_helicase.pkl
# all_preds_grampos_phosphorylation.pkl
# all_preds_gramneg_toxin.pkl
# all_preds_grampos_lysin.pkl
# all_preds_gramneg_head-tail_joining.pkl
# all_preds_grampos_RNA-associated.pkl
# all_preds_gramneg_phosphorylation.pkl
# all_preds_grampos_primase.pkl
# all_preds_grampos_toxin.pkl
# all_preds_grampos_ejection.pkl
# all_preds_grampos_pvp.pkl
# all_preds_grampos_holin.pkl
# all_preds_gramneg_tail_appendage.pkl
# all_preds_grampos_baseplate.pkl
# all_preds_gramneg_RNA-associated.pkl
# all_preds_grampos_packaging_assembly.pkl

# %%
p1 = pd.read_pickle("../Data/random_pc_r_5_da_2_bal_s_2/all_preds_grampos_terminase.pkl")
print("Split 2 - Terminase", p1.shape)
print(p1.head(3))
print()
# Out:
# Split 2 - Terminase (18726, 16)
#                 Staphylococcus_terminase  Enterococcus_terminase  \
# proteinID
# AB009866_00001                  0.966656                0.214434
# AB009866_00002                  0.929699                0.353905
# AB016282_00001                  0.005482                0.003075
#
#                 Clostridium_terminase  Lactococcus_terminase  \
# proteinID
# AB009866_00001               0.010583               0.001224
# AB009866_00002               0.000076               0.074586
# AB016282_00001               0.010405               0.001395
#
#                 Mycobacterium_terminase  Streptococcus_terminase  \
# proteinID
# AB009866_00001             4.668422e-05                 0.011129
# AB009866_00002             4.641819e-07                 0.003600
# AB016282_00001             6.604176e-04                 0.000385
#
#                 Lactobacillus_terminase  Propionibacterium_terminase  \
# proteinID
# AB009866_00001                 0.001034                     0.000458
# AB009866_00002                 0.178849                     0.000195
# AB016282_00001                 0.023292                     0.002309
#
#                 Listeria_terminase  Corynebacterium_terminase  \
# proteinID
# AB009866_00001            0.000828                   0.000035
# AB009866_00002            0.000288                   0.000108
# AB016282_00001            0.000653                   0.000022
#
#                 Streptomyces_terminase  Paenibacillus_terminase  \
# proteinID
# AB009866_00001                0.000042                 0.003928
# AB009866_00002                0.000015                 0.043612
# AB016282_00001                0.000126                 0.001065
#
#                 Clostridioides_terminase  Microbacterium_terminase  \
# proteinID
# AB009866_00001                  0.000524              1.170032e-07
# AB009866_00002                  0.003236              1.179681e-06
# AB016282_00001                  0.000069              2.151353e-07
#
#                 Gordonia_terminase  Lacticaseibacillus_terminase
# proteinID
# AB009866_00001            0.000055                      0.086890
# AB009866_00002            0.000514                      0.075954
# AB016282_00001            0.000041                      0.058263

# %%
p1 = pd.read_pickle("../Data/random_pc_r_5_da_2_bal_s_2/all_preds_gramneg_spanin.pkl")
print("Split 2 - Spanin", p1.shape)
print(p1)
print()
# Out:
# Split 2 - Spanin (12956, 37)
#                 Vibrio_spanin  Pseudomonas_spanin  Salmonella_spanin  \
# proteinID
# AB102868_00041       0.000014            0.000505           0.779193
# AB255436_00010       0.000024            0.002726           0.724148
# AB276040_00016       0.000022            0.009923           0.005022
# AB285204_00054       0.000040            0.001264           0.724288
# AB362338_00060       0.000025            0.000385           0.870239
# ...                       ...                 ...                ...
# OY979771_00263       0.001170            0.067629           0.237897
# U24159_00034         0.414325            0.000860           0.017008
# U32222_00011         0.000196            0.002505           0.866094
# U32222_00012         0.000009            0.007951           0.850708
# V01146_00048         0.000055            0.002674           0.042706
#
#                 Microcystis_spanin  Escherichia_spanin  Ralstonia_spanin  \
# proteinID
# AB102868_00041            0.009674            0.862443          0.001237
# AB255436_00010            0.010397            0.956220          0.000642
# AB276040_00016            0.036797            0.013154          0.978961
# AB285204_00054            0.009894            0.937299          0.000482
# AB362338_00060            0.008916            0.924727          0.000186
# ...                            ...                 ...               ...
# OY979771_00263            0.008534            0.929725          0.000135
# U24159_00034              0.015239            0.385074          0.000157
# U32222_00011              0.052334            0.803008          0.000484
# U32222_00012              0.030801            0.049628          0.000772
# V01146_00048              0.018528            0.096842          0.004478
#
#                 Klebsiella_spanin  Xanthomonas_spanin  Edwardsiella_spanin  \
# proteinID
# AB102868_00041           0.172769            0.000134             0.047559
# AB255436_00010           0.196324            0.000096             0.033074
# AB276040_00016           0.005758            0.004378             0.103539
# AB285204_00054           0.074361            0.000086             0.026561
# AB362338_00060           0.016349            0.000099             0.042056
# ...                           ...                 ...                  ...
# OY979771_00263           0.006862            0.001577             0.049285
# U24159_00034             0.001505            0.000104             0.002653
# U32222_00011             0.421462            0.000010             0.005331
# U32222_00012             0.010419            0.029874             0.002848
# V01146_00048             0.098688            0.000537             0.284251
#
#                 Pseudoalteromonas_spanin  ...  Caulobacter_spanin  \
# proteinID                                 ...
# AB102868_00041                  0.001959  ...            0.000022
# AB255436_00010                  0.001946  ...            0.000024
# AB276040_00016                  0.003136  ...            0.027225
# AB285204_00054                  0.001796  ...            0.000018
# AB362338_00060                  0.002770  ...            0.000015
# ...                                  ...  ...                 ...
# OY979771_00263                  0.005167  ...            0.000509
# U24159_00034                    0.003986  ...            0.000383
# U32222_00011                    0.002812  ...            0.000039
# U32222_00012                    0.004466  ...            0.005356
# V01146_00048                    0.012440  ...            0.000299
#
#                 Dickeya_spanin  Cronobacter_spanin  Cellulophaga_spanin  \
# proteinID
# AB102868_00041        0.233991            0.851139             0.004975
# AB255436_00010        0.089595            0.800763             0.005437
# AB276040_00016        0.026746            0.044352             0.007310
# AB285204_00054        0.143315            0.788412             0.004577
# AB362338_00060        0.216776            0.861109             0.005116
# ...                        ...                 ...                  ...
# OY979771_00263        0.001678            0.026403             0.007397
# U24159_00034          0.014101            0.029617             0.004119
# U32222_00011          0.004562            0.009158             0.004062
# U32222_00012          0.011170            0.004061             0.004339
# V01146_00048          0.168766            0.030631             0.004730
#
#                 Rhodobacter_spanin  Pectobacterium_spanin  Providencia_spanin  \
# proteinID
# AB102868_00041            0.000740               0.008246            0.003262
# AB255436_00010            0.001108               0.003104            0.002357
# AB276040_00016            0.004825               0.006826            0.002522
# AB285204_00054            0.000732               0.007978            0.001342
# AB362338_00060            0.000961               0.006540            0.006049
# ...                            ...                    ...                 ...
# OY979771_00263            0.000256               0.004314            0.019023
# U24159_00034              0.000575               0.051488            0.044438
# U32222_00011              0.001986               0.000361            0.126281
# U32222_00012              0.001742               0.001341            0.000950
# V01146_00048              0.001256               0.016644            0.036380
#
#                 Serratia_spanin  Pelagibacter_spanin  Shewanella_spanin
# proteinID
# AB102868_00041         0.010624             0.003225           0.000603
# AB255436_00010         0.004455             0.003887           0.000815
# AB276040_00016         0.061677             0.000486           0.001861
# AB285204_00054         0.007194             0.003974           0.000513
# AB362338_00060         0.008543             0.003395           0.000453
# ...                         ...                  ...                ...
# OY979771_00263         0.900536             0.000781           0.001293
# U24159_00034           0.035497             0.001883           0.012685
# U32222_00011           0.007478             0.002255           0.017837
# U32222_00012           0.002422             0.002315           0.000062
# V01146_00048           0.192673             0.002053           0.000111
#
# [12956 rows x 37 columns]

# %%
folder_path = Path("../Data/random_pc_r_5_da_2_bal_s_3")

# Print all files in the folder
for file in folder_path.iterdir():
    if file.is_file():
        print(file.name)
# Out:
# all_preds_grampos_terminase.pkl
# all_preds_grampos_adsorption-related.pkl
# all_preds_gramneg_spanin.pkl
# all_preds_gramneg_val.pkl
# all_preds_gramneg_cell_wall_depolymerase.pkl
# all_preds_gramneg_transcriptional_activator.pkl
# all_preds_gramneg_endolysin.pkl
# all_preds_gramneg_super_infection.pkl
# all_preds_grampos_transcriptional_repressor.pkl
# all_preds_gramneg_transcriptional_repressor.pkl
# all_preds_grampos_DNA_polymerase.pkl
# all_preds_grampos_nuclease.pkl
# all_preds_grampos_sir2.pkl
# all_preds_grampos_tail.pkl
# all_preds_gramneg_tail_sheath.pkl
# all_preds_gramneg_nucleotide_metabolism.pkl
# all_preds_grampos_spanin.pkl
# all_preds_grampos_integration.pkl
# all_preds_grampos_transferase.pkl
# all_preds_gramneg_nuclease.pkl
# all_preds_gramneg_replication_initiation.pkl
# all_preds_gramneg_reductase.pkl
# all_preds_grampos_nucleotide_metabolism.pkl
# all_preds_grampos_transcriptional_regulator.pkl
# all_preds_gramneg_integration.pkl
# all_preds_gramneg_lysis.pkl
# all_preds_gramneg_sir2.pkl
# all_preds_gramneg_adsorption-related.pkl
# all_preds_grampos_transcriptional_activator.pkl
# all_preds_grampos_tail_sheath.pkl
# all_preds_gramneg_tail.pkl
# all_preds_gramneg_pvp.pkl
# all_preds_gramneg_terminase.pkl
# all_preds_grampos_anti-restriction.pkl
# all_preds_grampos_DNA-associated.pkl
# all_preds_gramneg_holin.pkl
# all_preds_gramneg_primase.pkl
# all_preds_grampos_lysis_inhibitor.pkl
# all_preds_grampos_lysis.pkl
# all_preds_gramneg_baseplate.pkl
# all_preds_gramneg_ejection.pkl
# all_preds_gramneg_lysin.pkl
# all_preds_grampos_reductase.pkl
# all_preds_gramneg_transferase.pkl
# all_preds_grampos_portal.pkl
# all_preds_grampos_capsid.pkl
# all_preds_gramneg_annealing.pkl
# all_preds_grampos_endolysin.pkl
# all_preds_gramneg_transcriptional_regulator.pkl
# all_preds_grampos_head-tail_joining.pkl
# all_preds_gramneg_DNA_polymerase.pkl
# all_preds_gramneg_capsid.pkl
# all_preds_gramneg_anti-restriction.pkl
# all_preds_grampos_replication_initiation.pkl
# all_preds_grampos_val.pkl
# all_preds_gramneg_DNA-associated.pkl
# all_preds_grampos_super_infection.pkl
# all_preds_gramneg_portal.pkl
# all_preds_grampos_annealing.pkl
# all_preds_grampos_cell_wall_depolymerase.pkl
# all_preds_grampos_tail_appendage.pkl
# all_preds_gramneg_lysis_inhibitor.pkl
# all_preds_gramneg_helicase.pkl
# all_preds_gramneg_packaging_assembly.pkl
# all_preds_grampos_helicase.pkl
# all_preds_grampos_phosphorylation.pkl
# all_preds_gramneg_toxin.pkl
# all_preds_grampos_lysin.pkl
# all_preds_gramneg_head-tail_joining.pkl
# all_preds_grampos_RNA-associated.pkl
# all_preds_gramneg_phosphorylation.pkl
# all_preds_grampos_primase.pkl
# all_preds_grampos_toxin.pkl
# all_preds_grampos_ejection.pkl
# all_preds_grampos_pvp.pkl
# all_preds_grampos_holin.pkl
# all_preds_gramneg_tail_appendage.pkl
# all_preds_grampos_baseplate.pkl
# all_preds_gramneg_RNA-associated.pkl
# all_preds_grampos_packaging_assembly.pkl

# %%
p1 = pd.read_pickle("../Data/random_pc_r_5_da_2_bal_s_3/all_preds_grampos_terminase.pkl")
print("Split 3 - Terminase", p1.shape)
print(p1.head(3))
print()
# Out:
# Split 3 - Terminase (18726, 16)
#                 Staphylococcus_terminase  Enterococcus_terminase  \
# proteinID
# AB009866_00001                  0.191084                0.236273
# AB009866_00002                  0.945549                0.035537
# AB016282_00001                  0.001170                0.002818
#
#                 Clostridium_terminase  Lactococcus_terminase  \
# proteinID
# AB009866_00001               0.008550               0.000393
# AB009866_00002               0.000023               0.000728
# AB016282_00001               0.007929               0.002015
#
#                 Mycobacterium_terminase  Streptococcus_terminase  \
# proteinID
# AB009866_00001             4.900030e-05                 0.004233
# AB009866_00002             5.740957e-07                 0.003968
# AB016282_00001             3.942894e-04                 0.045039
#
#                 Lactobacillus_terminase  Propionibacterium_terminase  \
# proteinID
# AB009866_00001                 0.000374                     0.000734
# AB009866_00002                 0.258232                     0.000204
# AB016282_00001                 0.053863                     0.001250
#
#                 Listeria_terminase  Corynebacterium_terminase  \
# proteinID
# AB009866_00001        2.494217e-05               1.000000e-07
# AB009866_00002        9.653223e-07               1.000000e-07
# AB016282_00001        2.254483e-05               1.000000e-07
#
#                 Streptomyces_terminase  Paenibacillus_terminase  \
# proteinID
# AB009866_00001                0.000003                 0.144650
# AB009866_00002                0.000004                 0.049370
# AB016282_00001                0.000012                 0.183019
#
#                 Clostridioides_terminase  Microbacterium_terminase  \
# proteinID
# AB009866_00001                  0.000263                  0.000001
# AB009866_00002                  0.013790                  0.000003
# AB016282_00001                  0.000065                  0.000001
#
#                 Gordonia_terminase  Lacticaseibacillus_terminase
# proteinID
# AB009866_00001            0.000058                      0.021477
# AB009866_00002            0.000057                      0.076674
# AB016282_00001            0.000056                      0.031546

# %%
p1 = pd.read_pickle("../Data/random_pc_r_5_da_2_bal_s_3/all_preds_gramneg_spanin.pkl")
print("Split 3 - Spanin", p1.shape)
print(p1)
print()
# Out:
# Split 3 - Spanin (12956, 36)
#                 Vibrio_spanin  Pseudomonas_spanin  Salmonella_spanin  \
# proteinID
# AB102868_00041       0.000881            0.000054           0.027514
# AB255436_00010       0.000235            0.000140           0.018071
# AB276040_00016       0.000009            0.404374           0.004914
# AB285204_00054       0.000285            0.000038           0.044796
# AB362338_00060       0.001085            0.000015           0.054291
# ...                       ...                 ...                ...
# OY979771_00263       0.000886            0.006647           0.010198
# U24159_00034         0.111790            0.000773           0.031820
# U32222_00011         0.000015            0.001758           0.009785
# U32222_00012         0.000003            0.008152           0.001824
# V01146_00048         0.000013            0.001659           0.016711
#
#                 Microcystis_spanin  Escherichia_spanin  Ralstonia_spanin  \
# proteinID
# AB102868_00041            0.010686            0.743327          0.001725
# AB255436_00010            0.011870            0.716705          0.000843
# AB276040_00016            0.020043            0.001651          0.945701
# AB285204_00054            0.011274            0.902236          0.000710
# AB362338_00060            0.007625            0.954744          0.000584
# ...                            ...                 ...               ...
# OY979771_00263            0.002899            0.915047          0.001365
# U24159_00034              0.029811            0.118050          0.000660
# U32222_00011              0.238236            0.570482          0.000160
# U32222_00012              0.026610            0.042089          0.002012
# V01146_00048              0.011216            0.896745          0.006169
#
#                 Klebsiella_spanin  Xanthomonas_spanin  Edwardsiella_spanin  \
# proteinID
# AB102868_00041           0.169607            0.000094             0.008619
# AB255436_00010           0.047078            0.000088             0.004655
# AB276040_00016           0.010233            0.001848             0.061950
# AB285204_00054           0.042745            0.000052             0.005237
# AB362338_00060           0.010188            0.000045             0.004442
# ...                           ...                 ...                  ...
# OY979771_00263           0.001633            0.000344             0.049959
# U24159_00034             0.003516            0.001100             0.006955
# U32222_00011             0.903022            0.000034             0.001019
# U32222_00012             0.008565            0.195084             0.007708
# V01146_00048             0.076622            0.000181             0.059674
#
#                 Pseudoalteromonas_spanin  ...  Caulobacter_spanin  \
# proteinID                                 ...
# AB102868_00041                  0.003427  ...            0.000382
# AB255436_00010                  0.003387  ...            0.000594
# AB276040_00016                  0.005837  ...            0.006600
# AB285204_00054                  0.003471  ...            0.000261
# AB362338_00060                  0.004672  ...            0.000270
# ...                                  ...  ...                 ...
# OY979771_00263                  0.051378  ...            0.001716
# U24159_00034                    0.003046  ...            0.002118
# U32222_00011                    0.003545  ...            0.000650
# U32222_00012                    0.013869  ...            0.188798
# V01146_00048                    0.013803  ...            0.001148
#
#                 Dickeya_spanin  Cronobacter_spanin  Cellulophaga_spanin  \
# proteinID
# AB102868_00041        0.036738            0.000552             0.000781
# AB255436_00010        0.007936            0.000554             0.000981
# AB276040_00016        0.001894            0.001529             0.001354
# AB285204_00054        0.019598            0.000490             0.000714
# AB362338_00060        0.023527            0.000855             0.000818
# ...                        ...                 ...                  ...
# OY979771_00263        0.000405            0.275847             0.000982
# U24159_00034          0.002808            0.003854             0.000356
# U32222_00011          0.000424            0.000960             0.000492
# U32222_00012          0.000828            0.038517             0.001480
# V01146_00048          0.124709            0.004031             0.000767
#
#                 Rhodobacter_spanin  Pectobacterium_spanin  Providencia_spanin  \
# proteinID
# AB102868_00041            0.000031               0.008338            0.028221
# AB255436_00010            0.000048               0.001946            0.015325
# AB276040_00016            0.000870               0.000619            0.002650
# AB285204_00054            0.000031               0.003082            0.013651
# AB362338_00060            0.000037               0.004718            0.041073
# ...                            ...                    ...                 ...
# OY979771_00263            0.000039               0.000823            0.003736
# U24159_00034              0.000036               0.091802            0.599712
# U32222_00011              0.000083               0.000064            0.211942
# U32222_00012              0.000513               0.000115            0.002379
# V01146_00048              0.000121               0.006229            0.019528
#
#                 Serratia_spanin  Pelagibacter_spanin  Shewanella_spanin
# proteinID
# AB102868_00041         0.007921             0.005048           0.000339
# AB255436_00010         0.002749             0.005718           0.000341
# AB276040_00016         0.005908             0.001166           0.012470
# AB285204_00054         0.003092             0.005419           0.000238
# AB362338_00060         0.005853             0.005914           0.000238
# ...                         ...                  ...                ...
# OY979771_00263         0.029160             0.001832           0.002862
# U24159_00034           0.027281             0.001994           0.001432
# U32222_00011           0.002884             0.004926           0.000469
# U32222_00012           0.002600             0.011413           0.011320
# V01146_00048           0.395038             0.004345           0.000330
#
# [12956 rows x 36 columns]

# %%
folder_path = Path("../Data/random_pc_r_5_da_2_bal_s_4")

# Print all files in the folder
for file in folder_path.iterdir():
    if file.is_file():
        print(file.name)
# Out:
# all_preds_grampos_terminase.pkl
# all_preds_grampos_adsorption-related.pkl
# all_preds_gramneg_spanin.pkl
# all_preds_gramneg_val.pkl
# all_preds_gramneg_cell_wall_depolymerase.pkl
# all_preds_gramneg_transcriptional_activator.pkl
# all_preds_gramneg_endolysin.pkl
# all_preds_gramneg_super_infection.pkl
# all_preds_grampos_transcriptional_repressor.pkl
# all_preds_gramneg_transcriptional_repressor.pkl
# all_preds_grampos_DNA_polymerase.pkl
# all_preds_grampos_nuclease.pkl
# all_preds_grampos_sir2.pkl
# all_preds_grampos_tail.pkl
# all_preds_gramneg_tail_sheath.pkl
# all_preds_gramneg_nucleotide_metabolism.pkl
# all_preds_grampos_spanin.pkl
# all_preds_grampos_integration.pkl
# all_preds_grampos_transferase.pkl
# all_preds_gramneg_nuclease.pkl
# all_preds_gramneg_replication_initiation.pkl
# all_preds_gramneg_reductase.pkl
# all_preds_grampos_nucleotide_metabolism.pkl
# all_preds_grampos_transcriptional_regulator.pkl
# all_preds_gramneg_integration.pkl
# all_preds_gramneg_lysis.pkl
# all_preds_gramneg_sir2.pkl
# all_preds_gramneg_adsorption-related.pkl
# all_preds_grampos_transcriptional_activator.pkl
# all_preds_grampos_tail_sheath.pkl
# all_preds_gramneg_tail.pkl
# all_preds_gramneg_pvp.pkl
# all_preds_gramneg_terminase.pkl
# all_preds_grampos_anti-restriction.pkl
# all_preds_grampos_DNA-associated.pkl
# all_preds_gramneg_holin.pkl
# all_preds_gramneg_primase.pkl
# all_preds_grampos_lysis_inhibitor.pkl
# all_preds_grampos_lysis.pkl
# all_preds_gramneg_baseplate.pkl
# all_preds_gramneg_ejection.pkl
# all_preds_gramneg_lysin.pkl
# all_preds_grampos_reductase.pkl
# all_preds_gramneg_transferase.pkl
# all_preds_grampos_portal.pkl
# all_preds_grampos_capsid.pkl
# all_preds_gramneg_annealing.pkl
# all_preds_grampos_endolysin.pkl
# all_preds_gramneg_transcriptional_regulator.pkl
# all_preds_grampos_head-tail_joining.pkl
# all_preds_gramneg_DNA_polymerase.pkl
# all_preds_gramneg_capsid.pkl
# all_preds_gramneg_anti-restriction.pkl
# all_preds_grampos_replication_initiation.pkl
# all_preds_grampos_val.pkl
# all_preds_gramneg_DNA-associated.pkl
# all_preds_grampos_super_infection.pkl
# all_preds_gramneg_portal.pkl
# all_preds_grampos_annealing.pkl
# all_preds_grampos_cell_wall_depolymerase.pkl
# all_preds_grampos_tail_appendage.pkl
# all_preds_gramneg_lysis_inhibitor.pkl
# all_preds_gramneg_helicase.pkl
# all_preds_gramneg_packaging_assembly.pkl
# all_preds_grampos_helicase.pkl
# all_preds_grampos_phosphorylation.pkl
# all_preds_gramneg_toxin.pkl
# all_preds_grampos_lysin.pkl
# all_preds_gramneg_head-tail_joining.pkl
# all_preds_grampos_RNA-associated.pkl
# all_preds_gramneg_phosphorylation.pkl
# all_preds_grampos_primase.pkl
# all_preds_grampos_toxin.pkl
# all_preds_grampos_ejection.pkl
# all_preds_grampos_pvp.pkl
# all_preds_grampos_holin.pkl
# all_preds_gramneg_tail_appendage.pkl
# all_preds_grampos_baseplate.pkl
# all_preds_gramneg_RNA-associated.pkl
# all_preds_grampos_packaging_assembly.pkl

# %%
p1 = pd.read_pickle("../Data/random_pc_r_5_da_2_bal_s_4/all_preds_grampos_terminase.pkl")
print("Split 4 - Terminase", p1.shape)
print(p1)
print()
# Out:
# Split 4 - Terminase (18726, 16)
#                 Staphylococcus_terminase  Enterococcus_terminase  \
# proteinID
# AB009866_00001                  0.989912                0.062960
# AB009866_00002                  0.967921                0.004629
# AB016282_00001                  0.016185                0.003317
# AB016282_00002                  0.000875                0.008250
# AB016282_00003                  0.523248                0.000823
# ...                                  ...                     ...
# X98106_00037                    0.000315                0.164177
# X98106_00038                    0.011248                0.001503
# X98106_00039                    0.000403                0.006762
# X99260_00018                    0.000008                0.500000
# Z47794_00020                    0.000119                0.279140
#
#                 Clostridium_terminase  Lactococcus_terminase  \
# proteinID
# AB009866_00001               0.005701               0.001885
# AB009866_00002               0.000504               0.002544
# AB016282_00001               0.021006               0.005191
# AB016282_00002               0.001142               0.000123
# AB016282_00003               0.000196               0.001302
# ...                               ...                    ...
# X98106_00037                 0.069227               0.006990
# X98106_00038                 0.032139               0.002553
# X98106_00039                 0.001335               0.001038
# X99260_00018                 0.028189               0.001045
# Z47794_00020                 0.988537               0.004250
#
#                 Mycobacterium_terminase  Streptococcus_terminase  \
# proteinID
# AB009866_00001             8.492332e-06                 0.001425
# AB009866_00002             1.000000e-07                 0.002947
# AB016282_00001             2.135606e-05                 0.004105
# AB016282_00002             6.214473e-07                 0.114460
# AB016282_00003             4.041826e-07                 0.452681
# ...                                 ...                      ...
# X98106_00037               4.183897e-06                 0.646264
# X98106_00038               3.181171e-07                 0.020550
# X98106_00039               9.787038e-04                 0.001184
# X99260_00018               8.141218e-05                 0.000063
# Z47794_00020               9.884639e-07                 0.829725
#
#                 Lactobacillus_terminase  Propionibacterium_terminase  \
# proteinID
# AB009866_00001                 0.000604                     0.000604
# AB009866_00002                 0.269137                     0.002492
# AB016282_00001                 0.033240                     0.002405
# AB016282_00002                 0.026927                     0.001863
# AB016282_00003                 0.013664                     0.002959
# ...                                 ...                          ...
# X98106_00037                   0.873330                     0.007166
# X98106_00038                   0.542584                     0.001521
# X98106_00039                   0.000514                     0.002947
# X99260_00018                   0.000369                     0.004431
# Z47794_00020                   0.000046                     0.003910
#
#                 Listeria_terminase  Corynebacterium_terminase  \
# proteinID
# AB009866_00001            0.000216                   0.002844
# AB009866_00002            0.000060                   0.003655
# AB016282_00001            0.000306                   0.002979
# AB016282_00002            0.000524                   0.005062
# AB016282_00003            0.000019                   0.002029
# ...                            ...                        ...
# X98106_00037              0.590378                   0.006264
# X98106_00038              0.000265                   0.002368
# X98106_00039              0.000141                   0.008685
# X99260_00018              0.000158                   0.000994
# Z47794_00020              0.000206                   0.001369
#
#                 Streptomyces_terminase  Paenibacillus_terminase  \
# proteinID
# AB009866_00001            5.554524e-05                 0.075367
# AB009866_00002            1.894788e-06                 0.007759
# AB016282_00001            1.319035e-04                 0.112658
# AB016282_00002            3.601316e-05                 0.168642
# AB016282_00003            4.713417e-05                 0.061189
# ...                                ...                      ...
# X98106_00037              8.831299e-07                 0.000799
# X98106_00038              4.593326e-05                 0.001267
# X98106_00039              9.013568e-03                 0.000783
# X99260_00018              4.095254e-06                 0.000076
# Z47794_00020              1.628588e-07                 0.000035
#
#                 Clostridioides_terminase  Microbacterium_terminase  \
# proteinID
# AB009866_00001                  0.001112              1.037317e-07
# AB009866_00002                  0.034333              1.970895e-07
# AB016282_00001                  0.000423              1.720444e-07
# AB016282_00002                  0.012844              1.065811e-06
# AB016282_00003                  0.008967              5.174501e-07
# ...                                  ...                       ...
# X98106_00037                    0.118511              1.189842e-04
# X98106_00038                    0.001218              1.000000e-07
# X98106_00039                    0.001651              3.321180e-04
# X99260_00018                    0.001195              7.646507e-04
# Z47794_00020                    0.003093              1.296158e-05
#
#                 Gordonia_terminase  Lacticaseibacillus_terminase
# proteinID
# AB009866_00001            0.000052                      0.493799
# AB009866_00002            0.000085                      0.402493
# AB016282_00001            0.000006                      0.225337
# AB016282_00002            0.000160                      0.038053
# AB016282_00003            0.000002                      0.001918
# ...                            ...                           ...
# X98106_00037              0.000002                      0.337885
# X98106_00038              0.000031                      0.539321
# X98106_00039              0.001343                      0.000147
# X99260_00018              0.000087                      0.000055
# Z47794_00020              0.000002                      0.000022
#
# [18726 rows x 16 columns]

# %%
p1 = pd.read_pickle("../Data/random_pc_r_5_da_2_bal_s_4/all_preds_gramneg_spanin.pkl")
print("Split 4 - Spanin", p1.shape)
print(p1)
print()
# Out:
# Split 4 - Spanin (12956, 36)
#                 Vibrio_spanin  Pseudomonas_spanin  Salmonella_spanin  \
# proteinID
# AB102868_00041   1.215055e-03            0.000956           0.790690
# AB255436_00010   6.002279e-04            0.003690           0.771645
# AB276040_00016   5.947136e-07            0.007098           0.011633
# AB285204_00054   9.081491e-04            0.001864           0.753337
# AB362338_00060   3.062556e-03            0.000490           0.860939
# ...                       ...                 ...                ...
# OY979771_00263   2.758431e-04            0.002267           0.016198
# U24159_00034     6.589093e-01            0.001733           0.032733
# U32222_00011     1.084589e-05            0.002558           0.873655
# U32222_00012     9.011961e-06            0.007192           0.731086
# V01146_00048     5.804741e-06            0.001975           0.398648
#
#                 Microcystis_spanin  Escherichia_spanin  Ralstonia_spanin  \
# proteinID
# AB102868_00041            0.020899            0.810054          0.001904
# AB255436_00010            0.019320            0.925163          0.001107
# AB276040_00016            0.048548            0.004905          0.992516
# AB285204_00054            0.021153            0.911557          0.000862
# AB362338_00060            0.017575            0.931716          0.000480
# ...                            ...                 ...               ...
# OY979771_00263            0.008651            0.238731          0.000663
# U24159_00034              0.026528            0.227871          0.000792
# U32222_00011              0.091681            0.888097          0.000867
# U32222_00012              0.022741            0.058102          0.000150
# V01146_00048              0.028785            0.900063          0.004802
#
#                 Klebsiella_spanin  Xanthomonas_spanin  Edwardsiella_spanin  \
# proteinID
# AB102868_00041           0.036895            0.000514             0.004215
# AB255436_00010           0.017640            0.000947             0.003903
# AB276040_00016           0.006769            0.003510             0.001004
# AB285204_00054           0.035449            0.000382             0.004964
# AB362338_00060           0.011496            0.000250             0.004780
# ...                           ...                 ...                  ...
# OY979771_00263           0.006401            0.002866             0.023441
# U24159_00034             0.008303            0.000507             0.005000
# U32222_00011             0.697211            0.000052             0.001196
# U32222_00012             0.006089            0.518175             0.002537
# V01146_00048             0.034133            0.000329             0.020950
#
#                 Pseudoalteromonas_spanin  ...  Caulobacter_spanin  \
# proteinID                                 ...
# AB102868_00041                  0.017273  ...            0.000304
# AB255436_00010                  0.016383  ...            0.000415
# AB276040_00016                  0.017074  ...            0.077804
# AB285204_00054                  0.016229  ...            0.000278
# AB362338_00060                  0.018516  ...            0.000179
# ...                                  ...  ...                 ...
# OY979771_00263                  0.046218  ...            0.000330
# U24159_00034                    0.011784  ...            0.001901
# U32222_00011                    0.017681  ...            0.000171
# U32222_00012                    0.030006  ...            0.186321
# V01146_00048                    0.021009  ...            0.000484
#
#                 Dickeya_spanin  Cronobacter_spanin  Cellulophaga_spanin  \
# proteinID
# AB102868_00041        0.024461            0.839187             0.001446
# AB255436_00010        0.009976            0.759623             0.001785
# AB276040_00016        0.011914            0.010047             0.003845
# AB285204_00054        0.015597            0.816519             0.001575
# AB362338_00060        0.020647            0.873200             0.001536
# ...                        ...                 ...                  ...
# OY979771_00263        0.001513            0.011580             0.002122
# U24159_00034          0.006790            0.061604             0.000747
# U32222_00011          0.002369            0.046827             0.000894
# U32222_00012          0.002540            0.031581             0.001571
# V01146_00048          0.443376            0.048242             0.001251
#
#                 Rhodobacter_spanin  Pectobacterium_spanin  Providencia_spanin  \
# proteinID
# AB102868_00041            0.000287               0.005890            0.005126
# AB255436_00010            0.000513               0.001409            0.002053
# AB276040_00016            0.016946               0.002622            0.005712
# AB285204_00054            0.000223               0.003376            0.003167
# AB362338_00060            0.000330               0.004751            0.008972
# ...                            ...                    ...                 ...
# OY979771_00263            0.000422               0.001891            0.003587
# U24159_00034              0.000117               0.069822            0.427053
# U32222_00011              0.000373               0.000306            0.013998
# U32222_00012              0.005505               0.000204            0.001175
# V01146_00048              0.001615               0.007141            0.042982
#
#                 Serratia_spanin  Pelagibacter_spanin  Shewanella_spanin
# proteinID
# AB102868_00041         0.019789             0.002986           0.008891
# AB255436_00010         0.005005             0.003539           0.006567
# AB276040_00016         0.050165             0.000598           0.011425
# AB285204_00054         0.008452             0.003771           0.005987
# AB362338_00060         0.010690             0.003571           0.006538
# ...                         ...                  ...                ...
# OY979771_00263         0.021818             0.001078           0.020994
# U24159_00034           0.008043             0.002558           0.046828
# U32222_00011           0.003873             0.003102           0.011166
# U32222_00012           0.002587             0.004830           0.002156
# V01146_00048           0.007964             0.002357           0.002705
#
# [12956 rows x 36 columns]
