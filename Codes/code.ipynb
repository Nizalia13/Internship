# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('host_type_all_preds.csv')

# View the first 5 rows
df.head()
# Out:
#         proteinID  host_type_lysin  host_type_endolysin  host_type_val  \
# 0  AB002632_00001              NaN                  NaN            NaN
# 1  AB002632_00002              NaN                  NaN            NaN
# 2  AB002632_00003              NaN                  NaN            NaN
# 3  AB002632_00004              NaN                  NaN            NaN
# 4  AB002632_00005              NaN                  NaN            NaN
#
#    host_type_capsid  host_type_baseplate  host_type_tail_appendage  \
# 0               NaN                  NaN                       NaN
# 1               NaN                  NaN                       NaN
# 2          0.029791                  NaN                       NaN
# 3               NaN                  NaN                       NaN
# 4          0.008570                  NaN                       NaN
#
#    host_type_tail_sheath  host_type_portal  host_type_head-tail_joining  ...  \
# ...

# %% [markdown]
# a prediction score from one of the ~40 function-specific models for a given host type (gram-positive or gram-negative — more on this below). So host_type_capsid = 0.029791 means "the capsid-function model gives this protein a 2.9% probability of being associated with this host type."
